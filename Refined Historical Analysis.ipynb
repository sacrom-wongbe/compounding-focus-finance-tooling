# %%
from __future__ import annotations

from dataclasses import dataclass
from typing import Dict, Iterable, Optional, Tuple, Union, List

import numpy as np
import pandas as pd
import yfinance as yf

# Optional: pretty display in notebooks
try:
    from IPython.display import display
except Exception:  # pragma: no cover
    display = None


def _as_datetime(x):
    if x is None:
        return None
    return pd.to_datetime(x)


def _fetch_prices(
    tickers,
    start: str,
    end: str | None,
    auto_adjust: bool = True,
) -> pd.DataFrame:
    """
    Robust price fetcher for yfinance across:
      - single vs multiple tickers
      - MultiIndex ticker/field ordering
      - auto_adjust True/False

    Returns a DataFrame with columns = tickers, values = adjusted close series.
    """
    tickers = list(tickers)

    df = yf.download(
        tickers=tickers,
        start=start,
        end=end,
        auto_adjust=auto_adjust,
        progress=False,
        group_by="ticker",
        threads=True,
    )

    if df is None or df.empty:
        return pd.DataFrame()

    # Decide which field we want
    # auto_adjust=True => "Close" is already adjusted
    wanted = "Close" if auto_adjust else "Adj Close"

    # --------
    # MultiIndex case
    # --------
    if isinstance(df.columns, pd.MultiIndex):
        lvl0 = df.columns.get_level_values(0)
        lvl1 = df.columns.get_level_values(1)

        # Case A: (ticker, field)
        if wanted in set(lvl1):
            px = df.xs(wanted, level=1, axis=1)
        # Case B: (field, ticker)
        elif wanted in set(lvl0):
            px = df.xs(wanted, level=0, axis=1)
        else:
            # Fallback: try Close then Adj Close
            for alt in ["Close", "Adj Close"]:
                if alt in set(lvl1):
                    px = df.xs(alt, level=1, axis=1)
                    break
                if alt in set(lvl0):
                    px = df.xs(alt, level=0, axis=1)
                    break
            else:
                raise KeyError(f"Could not find Close/Adj Close in columns: {df.columns}")

        px = px.copy()
        px.columns = [c.upper() for c in px.columns]  # normalize
        return px.dropna(how="all")

    # --------
    # Single-ticker (flat columns) case
    # --------
    if wanted in df.columns:
        s = df[wanted].copy()
    elif (not auto_adjust) and ("Close" in df.columns):
        # fallback if Adj Close missing
        s = df["Close"].copy()
    else:
        raise KeyError(f"Could not find '{wanted}' (or fallback) in columns: {df.columns.tolist()}")

    # If single ticker, return as DataFrame with that ticker name
    name = tickers[0].upper() if len(tickers) == 1 else "PRICE"
    return pd.DataFrame({name: s}).dropna(how="all")


def _returns(prices: pd.Series) -> pd.Series:
    r = prices.pct_change().replace([np.inf, -np.inf], np.nan)
    return r.dropna()


def _max_drawdown(prices: pd.Series) -> float:
    peak = prices.cummax()
    dd = prices / peak - 1.0
    return float(dd.min())


def _drawdown_series(prices: pd.Series) -> pd.Series:
    peak = prices.cummax()
    dd = prices / peak - 1.0
    return dd


def _ulcer_index(prices: pd.Series) -> float:
    dd = _drawdown_series(prices)
    # ulcer index uses drawdown in percent; square, average, sqrt
    dd_pct = (dd * 100.0).clip(upper=0)
    ui = float(np.sqrt(np.mean(np.square(dd_pct.values))))
    return ui


def _cagr(prices: pd.Series) -> float:
    if prices.shape[0] < 2:
        return np.nan
    start_val = float(prices.iloc[0])
    end_val = float(prices.iloc[-1])
    if start_val <= 0 or end_val <= 0:
        return np.nan
    days = (prices.index[-1] - prices.index[0]).days
    if days <= 0:
        return np.nan
    years = days / 365.25
    return float((end_val / start_val) ** (1 / years) - 1)


def _ann_vol(returns: pd.Series, periods_per_year: int = 252) -> float:
    if len(returns) < 2:
        return np.nan
    return float(returns.std(ddof=1) * np.sqrt(periods_per_year))


def _martin_ratio(prices: pd.Series, rf: float = 0.0) -> float:
    # Martin = (annualized return - rf)) / Ulcer Index
    ui = _ulcer_index(prices)
    if ui == 0 or np.isnan(ui):
        return np.nan
    ann = _cagr(prices)
    return float((ann - rf) / (ui / 100.0))  # ui was percent-based


def _time_underwater_stats(prices: pd.Series) -> Tuple[float, float, float, float]:
    """
    Returns:
      pct_days_underwater, avg_underwater_days, p95_underwater_days, max_underwater_days
    Underwater = price < prior peak.
    """
    if prices.shape[0] < 2:
        return (np.nan, np.nan, np.nan, np.nan)

    peak = prices.cummax()
    underwater = prices < peak

    # Identify contiguous underwater runs
    runs = []
    in_run = False
    run_start = None

    for dt, uw in underwater.items():
        if uw and not in_run:
            in_run = True
            run_start = dt
        elif (not uw) and in_run:
            # run ends at previous date; count business days in slice
            in_run = False
            run_end = dt
            # count rows between run_start and the day before run_end
            run_len = prices.loc[run_start:run_end].shape[0] - 1
            runs.append(max(run_len, 1))
            run_start = None

    if in_run and run_start is not None:
        run_len = prices.loc[run_start:].shape[0]
        runs.append(max(run_len, 1))

    pct = float(underwater.mean())
    if len(runs) == 0:
        return (pct, 0.0, 0.0, 0.0)

    runs_arr = np.array(runs, dtype=float)
    return (
        pct,
        float(np.mean(runs_arr)),
        float(np.percentile(runs_arr, 95)),
        float(np.max(runs_arr)),
    )


def _recovery_metrics(prices: pd.Series) -> Tuple[float, float, float, float]:
    """
    Period-local recovery notion:
      - Find the maximum drawdown peak->trough in the window.
      - Define "recovery" as trough -> reclaim that peak.
      Outputs:
        ttr_days, recovery_slope_annualized, recovery_efficiency, did_recover(0/1)
    """
    if prices.shape[0] < 5:
        return (np.nan, np.nan, np.nan, 0.0)

    peak = prices.cummax()
    dd = prices / peak - 1.0

    # Locate trough of worst drawdown
    trough_dt = dd.idxmin()
    trough_price = float(prices.loc[trough_dt])

    # Peak before trough that defines this drawdown
    pre = prices.loc[:trough_dt]
    if pre.shape[0] < 2:
        return (np.nan, np.nan, np.nan, 0.0)

    peak_dt = pre.idxmax()
    peak_price = float(prices.loc[peak_dt])

    if peak_price <= 0 or trough_price <= 0:
        return (np.nan, np.nan, np.nan, 0.0)

    max_dd = float((trough_price / peak_price) - 1.0)  # negative

    # Find first date after trough that reaches prior peak
    post = prices.loc[trough_dt:]
    recovered = post[post >= peak_price]
    if recovered.empty:
        # No recovery to old peak within window
        # Still can compute "slope" to end of window as partial recovery
        end_price = float(prices.iloc[-1])
        days = max((prices.index[-1] - trough_dt).days, 1)
        daily_slope = float(np.log(end_price / trough_price) / days) if end_price > 0 else np.nan
        ann_slope = float(np.exp(daily_slope * 252) - 1) if not np.isnan(daily_slope) else np.nan
        # Efficiency: partial return / abs(dd)
        partial_return = float((end_price / trough_price) - 1.0)
        eff = float(partial_return / abs(max_dd)) if max_dd != 0 else np.nan
        return (np.nan, ann_slope, eff, 0.0)

    rec_dt = recovered.index[0]
    ttr_days = max((rec_dt - trough_dt).days, 1)

    # log slope from trough to recovered peak
    daily_slope = float(np.log(peak_price / trough_price) / ttr_days)
    ann_slope = float(np.exp(daily_slope * 252) - 1)
    # recovery return from trough to peak
    rec_return = float((peak_price / trough_price) - 1.0)
    eff = float(rec_return / abs(max_dd)) if max_dd != 0 else np.nan
    return (float(ttr_days), ann_slope, eff, 1.0)


def _capital_efficiency_index(cagr: float, max_dd: float) -> float:
    """
    Capital Efficiency: CAGR / |MaxDD|
    Higher = better returns per unit of drawdown risk
    """
    if np.isnan(cagr) or np.isnan(max_dd) or max_dd >= 0:
        return np.nan
    return float(cagr / abs(max_dd))


def _volatility_drag_ratio(prices: pd.Series, returns: pd.Series) -> float:
    """
    Volatility Drag: geometric mean / arithmetic mean
    Ratio of actual compounded return to simple average return.
    Lower drag (closer to 1.0) is better.
    """
    if len(returns) < 2:
        return np.nan
    
    # Arithmetic mean return
    arith_mean = float(returns.mean())
    
    # Geometric mean: (ending / starting) ^ (1/n) - 1
    if prices.iloc[0] <= 0 or prices.iloc[-1] <= 0:
        return np.nan
    
    total_return = float(prices.iloc[-1] / prices.iloc[0]) - 1.0
    n_periods = len(returns)
    geom_mean = float((1 + total_return) ** (1 / n_periods) - 1)
    
    if arith_mean == 0:
        return np.nan
    return float(geom_mean / arith_mean)


def _pct_time_near_highs(prices: pd.Series, threshold_pct: float = 0.05) -> float:
    """
    % Time Near Highs: Percentage of days within threshold_pct of rolling peak
    threshold_pct: e.g., 0.05 for within 5% of peak
    """
    if prices.shape[0] < 2:
        return np.nan
    
    peak = prices.cummax()
    pct_below = (prices / peak - 1.0)  # negative values = below peak
    near_high = pct_below >= -threshold_pct
    
    return float(near_high.mean())


def _trend_persistence(returns: pd.Series) -> float:
    """
    Trend Persistence: % of days where return has same sign as previous day
    Higher = stronger momentum/trend, Lower = more mean reversion
    """
    if len(returns) < 2:
        return np.nan
    
    sign_change = np.sign(returns.values[:-1]) == np.sign(returns.values[1:])
    # Only count where neither is zero
    valid = (returns.values[:-1] != 0) & (returns.values[1:] != 0)
    
    if valid.sum() == 0:
        return np.nan
    
    return float(sign_change[valid].mean())


def _expected_shortfall(returns: pd.Series, percentile: float = 5.0) -> float:
    """
    Expected Shortfall (CVaR): Average of worst X% of returns
    percentile: e.g., 5.0 for worst 5%
    """
    if len(returns) < 10:
        return np.nan
    
    threshold = np.percentile(returns.values, percentile)
    worst = returns[returns <= threshold]
    
    if len(worst) == 0:
        return np.nan
    
    return float(worst.mean())


def _capture_ratio(etf_prices: pd.Series, bench_prices: pd.Series, side: str) -> float:
    """
    Upside/Downside capture within window:
      - Uses daily returns
      - For upside: only days benchmark return > 0
      - For downside: only days benchmark return < 0
      Ratio of compounded returns over those selected days
    """
    etf_r = _returns(etf_prices)
    bmk_r = _returns(bench_prices)

    aligned = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()
    
    if aligned.empty:
        return np.nan

    if side == "up":
        sel = aligned[aligned["bmk"] > 0]
    elif side == "down":
        sel = aligned[aligned["bmk"] < 0]
    else:
        raise ValueError("side must be 'up' or 'down'")

    if sel.empty:
        return np.nan

    etf_comp = float(np.prod(1.0 + sel["etf"].values) - 1.0)
    bmk_comp = float(np.prod(1.0 + sel["bmk"].values) - 1.0)
    if bmk_comp == 0:
        return np.nan
    return float(etf_comp / bmk_comp)


# --- Helper to normalize period values ---
def _normalize_period(val: Union[Tuple[str, Optional[str]], List[Optional[str]]]) -> Tuple[str, Optional[str]]:
    """
    Accepts period value as:
      - [start, end]
      - [start, None]
      - [start, end, trough]  (third element ignored)
    Returns (start, end) with end possibly None.
    """
    if isinstance(val, (list, tuple)):
        if len(val) >= 2:
            return val[0], val[1]
        raise ValueError("Period value must have at least [start, end_or_None]")
    raise ValueError(f"Unsupported period value type: {type(val)}")


def _period_metrics_for_series(
    etf_prices: pd.Series,
    bench_prices: Optional[pd.Series] = None,
    rf: float = 0.0,
) -> Dict[str, float]:
    r = _returns(etf_prices)

    maxdd = _max_drawdown(etf_prices)
    ui = _ulcer_index(etf_prices)
    cagr = _cagr(etf_prices)
    vol = _ann_vol(r)
    martin = _martin_ratio(etf_prices, rf=rf)

    pct_uw, avg_uw, p95_uw, max_uw = _time_underwater_stats(etf_prices)
    ttr, rec_slope, rec_eff, did_rec = _recovery_metrics(etf_prices)

    # New metrics
    cap_eff = _capital_efficiency_index(cagr, maxdd)
    vol_drag = _volatility_drag_ratio(etf_prices, r)
    pct_near_highs = _pct_time_near_highs(etf_prices)
    trend_pers = _trend_persistence(r)
    cvar = _expected_shortfall(r)

    # Period-level relative metrics (not rolling - calculated over full period)
    periods_per_year = 252
    period_corr = np.nan
    period_beta = np.nan
    period_alpha_per = np.nan
    period_r2 = np.nan
    te_ann = np.nan
    ir = np.nan
    cond_corr_up = np.nan
    cond_corr_down = np.nan
    period_alpha_ann = np.nan

    if bench_prices is not None:
        bmk_r = _returns(bench_prices)
        # Align returns
        aligned = pd.concat([r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()
        if len(aligned) >= 10:  # Need minimum data points
            etf_r = aligned["etf"]
            bmk_r = aligned["bmk"]
            
            # Full period correlation
            period_corr = float(etf_r.corr(bmk_r))
            
            # Full period beta/alpha/R2 using simple linear regression
            # beta = cov(etf, bmk) / var(bmk)
            cov_xy = etf_r.cov(bmk_r)
            var_x = bmk_r.var()
            
            if var_x > 0:
                period_beta = float(cov_xy / var_x)
                # alpha = mean(etf) - beta * mean(bmk)
                period_alpha_per = float(etf_r.mean() - period_beta * bmk_r.mean())
                # R² = correlation²
                period_r2 = float(period_corr ** 2)
                
                # Annualized alpha (simple scaling - for daily returns)
                period_alpha_ann = float(period_alpha_per * periods_per_year)
                
                # Tracking error: std(etf - bmk) annualized
                active_returns = etf_r - bmk_r
                te_ann = float(active_returns.std(ddof=1) * np.sqrt(periods_per_year))
                
                # Information ratio: annualized_alpha / tracking_error
                if te_ann > 0:
                    ir = float(period_alpha_ann / te_ann)
            
            # Conditional correlations (full period)
            # Correlation when benchmark is up
            up_mask = bmk_r > 0
            if up_mask.sum() >= 10:
                cond_corr_up = float(etf_r[up_mask].corr(bmk_r[up_mask]))
            
            # Correlation when benchmark is down
            down_mask = bmk_r < 0
            if down_mask.sum() >= 10:
                cond_corr_down = float(etf_r[down_mask].corr(bmk_r[down_mask]))

    out = {
        "CAGR": cagr,
        "AnnVol": vol,
        "MaxDD": maxdd,
        "UlcerIndex": ui,
        "Martin": martin,
        "CapitalEfficiency": cap_eff,
        "VolatilityDrag": vol_drag,
        "PctTimeNearHighs": pct_near_highs,
        "TrendPersistence": trend_pers,
        "ExpectedShortfall": cvar,
        "PctDaysUnderwater": pct_uw,
        "AvgUnderwaterDays": avg_uw,
        "P95UnderwaterDays": p95_uw,
        "MaxUnderwaterDays": max_uw,
        "TTR_Days": ttr,
        "RecoverySlope_Ann": rec_slope,
        "RecoveryEfficiency": rec_eff,
        "RecoveredToPeak_inWindow": did_rec,
        # Period-level relative metrics (vs benchmark)
        "PeriodCorr": period_corr,
        "PeriodBeta": period_beta,
        "PeriodAlpha_per_period": period_alpha_per,
        "PeriodAlpha_Ann": period_alpha_ann,
        "PeriodR2": period_r2,
        "TrackingError_Ann": te_ann,
        "InformationRatio": ir,
        "ConditionalCorr_Up": cond_corr_up,
        "ConditionalCorr_Down": cond_corr_down,
    }

    if bench_prices is not None:
        out["UpsideCapture"] = _capture_ratio(etf_prices, bench_prices, "up")
        out["DownsideCapture"] = _capture_ratio(etf_prices, bench_prices, "down")

    return out


def _format_styler(df: pd.DataFrame) -> "pd.io.formats.style.Styler":
    pct_cols = [c for c in df.columns if c in {
        "CAGR", "AnnVol", "MaxDD", "PctTimeNearHighs", "TrendPersistence",
        "RecoverySlope_Ann", "PeriodAlpha_per_period", "PeriodAlpha_Ann", "TrackingError_Ann"
    }]
    ratio_cols = [c for c in df.columns if "Capture" in c or c in {
        "Martin", "RecoveryEfficiency", "CapitalEfficiency", "VolatilityDrag",
        "InformationRatio", "PeriodR2"
    }]
    corr_beta_cols = [c for c in df.columns if c in {
        "PeriodCorr", "ConditionalCorr_Up", "ConditionalCorr_Down", "PeriodBeta"
    }]
    num_cols = [c for c in df.columns if c not in pct_cols + ratio_cols + corr_beta_cols]

    sty = df.style

    # Formats
    fmt = {c: "{:.2%}" for c in pct_cols}
    fmt.update({c: "{:.3f}" for c in ratio_cols})
    fmt.update({c: "{:.3f}" for c in corr_beta_cols})
    fmt.update({c: "{:.2f}" for c in num_cols if c not in fmt})

    # Special-case some columns
    if "UlcerIndex" in df.columns:
        fmt["UlcerIndex"] = "{:.2f}"
    if "PctDaysUnderwater" in df.columns:
        fmt["PctDaysUnderwater"] = "{:.1%}"
    if "ExpectedShortfall" in df.columns:
        fmt["ExpectedShortfall"] = "{:.2%}"
    for c in ["AvgUnderwaterDays", "P95UnderwaterDays", "MaxUnderwaterDays", "TTR_Days"]:
        if c in df.columns:
            fmt[c] = "{:.0f}"
    if "RecoveredToPeak_inWindow" in df.columns:
        fmt["RecoveredToPeak_inWindow"] = "{:.0f}"
    
    # Add DataAvailability column formatting
    if "DataAvailability" in df.columns:
        fmt["DataAvailability"] = "{:.1%}"

    sty = sty.format(fmt, na_rep="—")

    # Only apply gradient to columns that have at least one non-NaN value
    gradient_cols = []
    for c in df.columns:
        if c != "DataAvailability" and df[c].notna().any():
            gradient_cols.append(c)
    
    if gradient_cols:
        sty = sty.background_gradient(subset=gradient_cols)

    if "MaxDD" in df.columns:
        sty = sty.map(lambda v: "font-weight:600" if pd.notna(v) and v < 0 else "", subset=["MaxDD"])

    return sty


def analyze_regimes(
    tickers: Union[str, Iterable[str]],
    periods: Dict[str, Union[Tuple[str, Optional[str]], List[Optional[str]]]],
    benchmark: Optional[str] = "VTI",
    rf: float = 0.0,
    auto_adjust: bool = True,
    display_results: bool = True,
) -> Dict[str, pd.DataFrame]:
    """
    Analyze ETF behavior over multiple named time windows.

    periods: dict mapping name -> [start, end] or [start, end, trough].
    The third element (trough) is ignored; only start/end are used.

    **KEY FEATURE**: Handles ETFs with different inception dates by:
    - Using whatever data is available within each period
    - Adding a "DataAvailability" column showing % of period covered
    - Computing metrics based on the actual overlapping dates

    Usage:
      analyze_regimes(["QQQ","SPY","USMV"], periods=periods_dict, benchmark="VTI")

    Args:
      tickers: one ticker or list of tickers to analyze
      periods: dict mapping name -> (start, end). end can be None to mean "today"
      benchmark: benchmark ticker for upside/downside capture (None disables)
      rf: risk-free rate used in Martin ratio (annual, e.g. 0.02)
      auto_adjust: pass through to yfinance download
      display_results: if True and in IPython, displays styled tables

    Returns:
      dict mapping period name -> DataFrame (rows=tickers, cols=metrics + DataAvailability)
    """
    if isinstance(tickers, str):
        tick_list = [tickers]
    else:
        tick_list = list(tickers)

    results: Dict[str, pd.DataFrame] = {}

    for pname, pval in periods.items():
        # Normalize period value to (start, end)
        pstart, pend = _normalize_period(pval)

        pstart_dt = _as_datetime(pstart)
        pend_dt = _as_datetime(pend)

        if pstart_dt is None:
            raise ValueError(f"Period '{pname}' missing start date.")
        if pend_dt is not None and pend_dt <= pstart_dt:
            raise ValueError(f"Period '{pname}' has end <= start.")

        # Fetch prices for ETFs + benchmark in one call when possible
        fetch_list = tick_list.copy()
        bmk = None
        if benchmark:
            fetch_list = sorted(set(fetch_list + [benchmark]))
            bmk = benchmark

        # Fetch with wider date range to capture all possible data
        px = _fetch_prices(
            fetch_list, 
            start=str(pstart_dt.date()), 
            end=(None if pend_dt is None else str(pend_dt.date())), 
            auto_adjust=auto_adjust
        )

        if px.empty:
            continue

        # Calculate full period trading days for availability calculation
        full_period_end = pend_dt if pend_dt is not None else px.index.max()
        full_period_mask = (px.index >= pstart_dt) & (px.index <= full_period_end)
        full_period_days = full_period_mask.sum()

        rows = []
        idx = []

        bench_series = px[bmk].dropna() if (bmk and bmk in px.columns) else None

        for t in tick_list:
            if t not in px.columns:
                continue
            
            # Get ticker series and filter to period
            s_full = px[t].dropna()
            
            # Find actual overlap with requested period
            s = s_full.loc[pstart_dt: full_period_end]
            
            if len(s) < 10:  # Need minimum data for meaningful analysis
                continue
            
            # Calculate data availability
            actual_days = len(s)
            data_availability = actual_days / full_period_days if full_period_days > 0 else 0.0
            
            # Get benchmark data aligned to ETF dates
            b = None
            if bench_series is not None:
                b = bench_series.reindex(s.index).dropna()
                # Re-align s to b to ensure matching dates
                if len(b) > 0:
                    common_idx = s.index.intersection(b.index)
                    s = s.loc[common_idx]
                    b = b.loc[common_idx]

            if len(s) < 10:
                continue

            metrics = _period_metrics_for_series(
                s, 
                bench_prices=b if b is not None else None, 
                rf=rf
            )
            
            # Add data availability to metrics
            metrics["DataAvailability"] = data_availability
            
            rows.append(metrics)
            idx.append(t)

        if not rows:
            continue

        df = pd.DataFrame(rows, index=idx)

        # Sort columns with DataAvailability first
        col_order = [
            "DataAvailability",  # Show this first so users know coverage
            "CAGR", "AnnVol", "Martin", "CapitalEfficiency",
            "MaxDD", "UlcerIndex",
            "VolatilityDrag", "PctTimeNearHighs", "TrendPersistence",
            "PctDaysUnderwater", "AvgUnderwaterDays", "P95UnderwaterDays", "MaxUnderwaterDays",
            "TTR_Days", "RecoverySlope_Ann", "RecoveryEfficiency", "RecoveredToPeak_inWindow",
            "ExpectedShortfall",
            # Rolling analytics
            "RollingCorr", "ConditionalCorr_Up", "ConditionalCorr_Down",
            "RollingBeta", "RollingR2",
            "RollingAlpha_per_period", "RollingAlpha_Ann",
            "TrackingError_Ann", "InformationRatio",
            # Capture
            "UpsideCapture", "DownsideCapture",
        ]
        df = df[[c for c in col_order if c in df.columns] + [c for c in df.columns if c not in col_order]]

        results[pname] = df

        if display_results and display is not None:
            title = pd.DataFrame({
                "Period": [pname], 
                "Start": [str(pstart_dt.date())], 
                "End": [("today" if pend_dt is None else str(full_period_end.date()))]
            })
            display(title)
            display(_format_styler(df))

    return results


# -------------------------
# Rolling analytics helpers
# -------------------------
def _to_returns(px: pd.Series, freq: str = "D") -> pd.Series:
    """
    Convert price series to returns.
    freq:
      - "D": daily returns
      - "W": weekly returns (Fri close)
      - "M": monthly returns
    """
    px = px.dropna()
    if freq == "D":
        r = px.pct_change()
    elif freq == "W":
        r = px.resample("W-FRI").last().pct_change()
    elif freq == "M":
        r = px.resample("M").last().pct_change()
    else:
        raise ValueError("freq must be one of {'D','W','M'}")
    return r.replace([np.inf, -np.inf], np.nan).dropna()


def rolling_corr(etf_r: pd.Series, bmk_r: pd.Series, window: int) -> pd.Series:
    df = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()
    return df["etf"].rolling(window).corr(df["bmk"])


def rolling_beta_alpha(etf_r: pd.Series, bmk_r: pd.Series, window: int) -> pd.DataFrame:
    """
    OLS in each rolling window:
      etf = alpha + beta*bmk + eps

    Returns DataFrame columns: ['alpha', 'beta', 'r2']
    alpha is per-period (daily/weekly/monthly) alpha, NOT annualized.
    """
    df = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()

    # Rolling means
    mx = df["bmk"].rolling(window).mean()
    my = df["etf"].rolling(window).mean()

    # Rolling cov/var
    cov_xy = df["bmk"].rolling(window).cov(df["etf"])
    var_x  = df["bmk"].rolling(window).var()

    beta = cov_xy / var_x
    alpha = my - beta * mx

    # Rolling R^2: correlation squared is simpler and more stable
    corr = df["etf"].rolling(window).corr(df["bmk"])
    r2 = corr ** 2

    out = pd.DataFrame({"alpha": alpha, "beta": beta, "r2": r2})
    return out


def annualize_alpha(alpha_per_period: pd.Series, periods_per_year: int) -> pd.Series:
    """
    Convert per-period alpha (e.g., daily) into annualized additive approximation.
    For small alpha this is fine. If you prefer compounding, use exp/log.
    """
    return alpha_per_period * periods_per_year


def tracking_error(etf_r: pd.Series, bmk_r: pd.Series, window: int, periods_per_year: int) -> pd.Series:
    """
    Rolling annualized tracking error: std(etf - bmk) * sqrt(periods_per_year)
    """
    df = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()
    active = (df["etf"] - df["bmk"])
    return active.rolling(window).std(ddof=1) * np.sqrt(periods_per_year)


def information_ratio(
    alpha_per_period: pd.Series,
    te_annualized: pd.Series,
    periods_per_year: int
) -> pd.Series:
    """
    Rolling Information Ratio:
      IR = annualized_alpha / annualized_tracking_error
    alpha_per_period should align with te_annualized index.
    """
    ann_alpha = annualize_alpha(alpha_per_period, periods_per_year)
    return ann_alpha / te_annualized.replace(0, np.nan)


def conditional_corr(
    etf_r: pd.Series,
    bmk_r: pd.Series,
    window: int,
    condition: str = "down"
) -> pd.Series:
    """
    Rolling correlation computed only on observations inside each window
    where benchmark return is <0 (down) or >0 (up).

    Note: This is more expensive than plain rolling corr because the set
    of points changes per window. For typical ETF daily data it's fine.
    """
    df = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()

    def _corr_in_window(idx: pd.Index) -> float:
        x = df.loc[idx]
        if condition == "down":
            sub = x[x["bmk"] < 0]
        elif condition == "up":
            sub = x[x["bmk"] > 0]
        else:
            raise ValueError("condition must be 'down' or 'up'")
        if len(sub) < max(10, window // 5):  # require some minimum points
            return np.nan
        return float(sub["etf"].corr(sub["bmk"]))

    # Apply rolling to one column, use its index to get full DataFrame slice
    return df["etf"].rolling(window).apply(lambda w: _corr_in_window(w.index), raw=False)

# %%
periods = {
    "Full History": [
      "2016-01-01",
      None
    ],
    "DotCom Bubble Drawdown": [
      "2001-06-02",
      "2004-12-04",
      "2002-10-09"
    ],
    "2005 Bull": [
      "2004-12-04",
      "2006-04-08"
    ],
    "2006 Inflation Consolidation": [
      "2006-04-08",
      "2006-11-26",
      "2006-06-13"
    ],
    "2007 Bull": [
      "2006-11-26",
      "2007-06-13"
    ],
    "GFC Drawdown": [
      "2007-06-13",
      "2012-04-26",
      "2009-03-09"
    ],
    "Eurozone Consolidation": [
      "2012-03-02",
      "2012-10-14",
      "2012-06-04"
    ],
    "2012–2015 Bull": [
      "2012-10-14",
      "2015-05-23"
    ],
    "2015-2016 Selloff Drawdown": [
      "2015-05-23",
      "2016-09-15",
      "2016-02-11"
    ],
    "2016-2017 Bull": [
      "2016-09-15",
      "2017-12-26"
    ],
    "Volmageddon Drawdown": [
      "2017-12-26",
      "2019-05-23",
      "2018-12-24"
    ],
    "2019-2020 Bull": [
      "2019-05-23",
      "2020-01-19"
    ],
    "Covid Drawdown": [
      "2020-01-19",
      "2020-09-28",
      "2020-03-23"
    ],
    "Leadership Rotation Consolidation": [
      "2020-08-02",
      "2020-12-27",
      "2020-09-23"
    ],
    "2021 Bull": [
      "2020-12-27",
      "2021-12-03"
    ],
    "2022 Rate Hike Drawdown": [
      "2021-12-03",
      "2024-03-02",
      "2022-10-12"
    ],
    "2024 Bull": [
      "2024-03-02",
      "2024-06-16"
    ],
    "2024 Consolidation": [
      "2024-06-16",
      "2024-12-06",
      "2024-08-05"
    ],
    "2025 Transition Bull": [
      "2024-12-06",
      "2025-01-19"
    ],
    "Trump Tariffs Drawdown and AI Bubble Fears": [
      "2025-01-19",
      None,
      "2025-04-08"
    ]
  }

# %%
ticker_list = ["VTI", "QQQ", 'VONG', 'VOOG', 'SCHG']

# %%
analyze_regimes(ticker_list, periods=periods, benchmark="VTI", rf=0.0)
print("done")
# Out:
#          Period       Start    End
# 0  Full History  2016-01-01  today
# <style type="text/css">
# #T_3aa30_row0_col1, #T_3aa30_row0_col2, #T_3aa30_row0_col4, #T_3aa30_row0_col6, #T_3aa30_row0_col9, #T_3aa30_row0_col11, #T_3aa30_row0_col12, #T_3aa30_row0_col13, #T_3aa30_row0_col14, #T_3aa30_row0_col17, #T_3aa30_row0_col21, #T_3aa30_row0_col23, #T_3aa30_row0_col24, #T_3aa30_row0_col26, #T_3aa30_row0_col27, #T_3aa30_row0_col28, #T_3aa30_row1_col8, #T_3aa30_row1_col17, #T_3aa30_row1_col18, #T_3aa30_row1_col19, #T_3aa30_row1_col20, #T_3aa30_row1_col25, #T_3aa30_row1_col29, #T_3aa30_row2_col10, #T_3aa30_row2_col16, #T_3aa30_row2_col17, #T_3aa30_row3_col3, #T_3aa30_row3_col15, #T_3aa30_row3_col17, #T_3aa30_row3_col22, #T_3aa30_row4_col7, #T_3aa30_row4_col17 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3aa30_row0_col3, #T_3aa30_row4_col6 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_3aa30_row0_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
#   font-weight: 600;
# }
# #T_3aa30_row0_col7, #T_3aa30_row0_col8, #T_3aa30_row0_col15, #T_3aa30_row0_col18, #T_3aa30_row0_col19, #T_3aa30_row0_col20, #T_3aa30_row0_col25, #T_3aa30_row0_col29, #T_3aa30_row1_col1, #T_3aa30_row1_col2, #T_3aa30_row1_col3, #T_3aa30_row1_col4, #T_3aa30_row1_col11, #T_3aa30_row1_col16, #T_3aa30_row1_col21, #T_3aa30_row1_col22, #T_3aa30_row1_col23, #T_3aa30_row1_col24, #T_3aa30_row1_col26, #T_3aa30_row1_col27, #T_3aa30_row1_col28, #T_3aa30_row3_col6, #T_3aa30_row3_col10, #T_3aa30_row3_col12, #T_3aa30_row3_col13, #T_3aa30_row3_col14, #T_3aa30_row4_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3aa30_row0_col10, #T_3aa30_row1_col9, #T_3aa30_row3_col9 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_3aa30_row0_col16 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_3aa30_row0_col22 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_3aa30_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# #T_3aa30_row1_col6 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_3aa30_row1_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_3aa30_row1_col10, #T_3aa30_row4_col21 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_3aa30_row1_col12 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_3aa30_row1_col13 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_3aa30_row1_col14 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_3aa30_row1_col15 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_3aa30_row2_col1, #T_3aa30_row2_col3 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col2 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col4 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_3aa30_row2_col6 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col7, #T_3aa30_row4_col27, #T_3aa30_row4_col28 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col8, #T_3aa30_row4_col19 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_3aa30_row2_col9 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col11 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col12 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col13 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_3aa30_row2_col14 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col15 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_3aa30_row2_col18 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_3aa30_row2_col19, #T_3aa30_row3_col18 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_3aa30_row2_col20 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_3aa30_row2_col21, #T_3aa30_row2_col24 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col22 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col23 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_3aa30_row2_col25, #T_3aa30_row4_col20 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_3aa30_row2_col26 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col27, #T_3aa30_row2_col28, #T_3aa30_row3_col21 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_3aa30_row2_col29 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_3aa30_row3_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_3aa30_row3_col2 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_3aa30_row3_col4 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_3aa30_row3_col5 {
#   background-color: #02395a;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_3aa30_row3_col7, #T_3aa30_row3_col23 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_3aa30_row3_col8, #T_3aa30_row4_col18 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_3aa30_row3_col11 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_3aa30_row3_col16 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_3aa30_row3_col19 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_3aa30_row3_col20 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_3aa30_row3_col24 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_3aa30_row3_col25 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_3aa30_row3_col26 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_3aa30_row3_col27, #T_3aa30_row3_col28 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_3aa30_row3_col29 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_3aa30_row4_col1 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col2 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col3 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_3aa30_row4_col4 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col5 {
#   background-color: #d7d6e9;
#   color: #000000;
#   font-weight: 600;
# }
# #T_3aa30_row4_col8 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_3aa30_row4_col10 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_3aa30_row4_col11 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_3aa30_row4_col12 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col13 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col14 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col15 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_3aa30_row4_col16 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col22 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_3aa30_row4_col23 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col24 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col25 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_3aa30_row4_col26 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_3aa30_row4_col29 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# </style>
# <table id="T_3aa30">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3aa30_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_3aa30_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_3aa30_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_3aa30_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_3aa30_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_3aa30_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_3aa30_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_3aa30_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_3aa30_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_3aa30_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_3aa30_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_3aa30_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_3aa30_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_3aa30_level0_col13" class="col_heading
# $VOOG: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $SCHG: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $VONG: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
#
# 3 Failed downloads:
# ['VOOG', 'SCHG', 'VONG']: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
#                    Period       Start         End
# 0  DotCom Bubble Drawdown  2001-06-02  2004-12-04
# <style type="text/css">
# #T_1683c_row0_col1, #T_1683c_row0_col3, #T_1683c_row0_col4, #T_1683c_row0_col7, #T_1683c_row0_col8, #T_1683c_row0_col15, #T_1683c_row0_col17, #T_1683c_row0_col18, #T_1683c_row0_col19, #T_1683c_row0_col20, #T_1683c_row0_col25, #T_1683c_row0_col27, #T_1683c_row0_col28, #T_1683c_row0_col29, #T_1683c_row1_col2, #T_1683c_row1_col6, #T_1683c_row1_col9, #T_1683c_row1_col10, #T_1683c_row1_col11, #T_1683c_row1_col12, #T_1683c_row1_col13, #T_1683c_row1_col16, #T_1683c_row1_col21, #T_1683c_row1_col23, #T_1683c_row1_col24, #T_1683c_row1_col26 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1683c_row0_col2, #T_1683c_row0_col6, #T_1683c_row0_col9, #T_1683c_row0_col10, #T_1683c_row0_col11, #T_1683c_row0_col12, #T_1683c_row0_col13, #T_1683c_row0_col14, #T_1683c_row0_col16, #T_1683c_row0_col21, #T_1683c_row0_col22, #T_1683c_row0_col23, #T_1683c_row0_col24, #T_1683c_row0_col26, #T_1683c_row1_col1, #T_1683c_row1_col3, #T_1683c_row1_col4, #T_1683c_row1_col7, #T_1683c_row1_col8, #T_1683c_row1_col14, #T_1683c_row1_col15, #T_1683c_row1_col17, #T_1683c_row1_col18, #T_1683c_row1_col19, #T_1683c_row1_col20, #T_1683c_row1_col22, #T_1683c_row1_col25, #T_1683c_row1_col27, #T_1683c_row1_col28, #T_1683c_row1_col29 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1683c_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_1683c_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# </style>
# <table id="T_1683c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1683c_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_1683c_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_1683c_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_1683c_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_1683c_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_1683c_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_1683c_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_1683c_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_1683c_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_1683c_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_1683c_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_1683c_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_1683c_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_1683c_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_1683c_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_1683c_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_1683c_level0_col16" class="col_heading level0 col16" >RecoveryEfficiency</th>
#       <th id="T_1683c_level0_col17" class="col_heading level0 col17" >RecoveredToPeak_inWindow</th>
#       <th id="T_1683c_level0_col18" class="col_heading level0 col18" >ExpectedShortfall</th>
#       <th id="T_1683c_level0_col19" class="col_heading level0 col19" >ConditionalCorr_Up</th>
#       <th id="T_1683c_level0_col20" class="col_heading level0 col20" >ConditionalCorr_Down</th>
#       <th id="T_1683c_level0_col21" class="col_heading level0 col21" >TrackingError_Ann</th>
#       <th id="T_1683c_level0_col22" class="col_heading level0 col22" >InformationRatio</th>
#       <th id="T_1683c_level0_col23" class="col_heading level0 col23" >UpsideCapture</th>
#       <th id="T_1683c_level0_col24" class="col_heading level0 col24" >DownsideCapture</th>
#       <th id="T_1683c_level0_col25" class="col_heading level0 col25" >PeriodCorr</th>
#       <th id="T_1683c_level0_col26" class="col_heading level0 col26" >PeriodBeta</th>
#       <th id="T_1683c_level0_col27" class="col_heading level0 col27" >PeriodAlpha_per_period</th>
#       <th id="T_1683c_level0_col28" class="col_heading level0 col28" >PeriodAlpha_Ann</th>
#       <th id="T_1683c_level0_col29" class="col_heading level0 col29" >PeriodR2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1683c_level0_row0" class="row_heading level0 row0" >VTI</th>
#       <td id="T_1683c_row0_col0" class="data row0 col0" >99.0%</td>
#       <td id="T_1683c_row0_col1" class="data row0 col1" >2.72%</td>
#       <td id="T_1683c_row0_col2" class="data row0 col2" >18.96%</td>
#       <td id="T_1683c_row0_col3" class="data row0 col3" >0.182</td>
#       <td id="T_1683c_row0_col4" class="data row0 col4" >0.078</td>
#       <td id="T_1683c_row0_col5" class="data row0 col5" >-34.66%</td>
#       <td id="T_1683c_row0_col6" class="data row0 col6" >14.93</td>
#       <td id="T_1683c_row0_col7" class="data row0 col7" >0.600</td>
#       <td id="T_1683c_row0_col8" class="data row0 col8" >30.42%</td>
#       <td id="T_1683c_row0_col9" class="data row0 col9" >47.50%</td>
#       <td id="T_1683c_row0_col10" class="data row0 col10" >97.4%</td>
#       <td id="T_1683c_row0_col11" class="data row0 col11" >65</td>
#       <td id="T_1683c_row0_col12" class="data row0 col12" >355</td>
#       <td id="T_1683c_row0_col13" class="data row0 col13" >635</td>
#       <td id="T_1683c_row0_col14" class="data row0 col14" >463</td>
#       <td id="T_1683c_row0_col15" class="data row0 col15" >26.06%</td>
#       <td id="T_1683c_row0_col16" class="data row0 col16" >1.530</td>
#       <td id="T_1683c_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_1683c_row0_col18" class="data row0 col18" >-2.55%</td>
#       <td id="T_1683c_row0_col19" class="data row0 col19" >1.000</td>
#       <td id="T_1683c_row0_col20" class="data row0 col20" >1.000</td>
#       <td id="T_1683c_row0_col21" class="data row0 col21" >0.00%</td>
#       <td id="T_1683c_row0_col22" class="data row0 col22" >—</td>
#       <td id="T_1683c_row0_col23" class="data row0 col23" >1.000</td>
#       <td id="T_1683c_row0_col24" class="data row0 col24" >1.000</td>
#       <td id="T_1683c_row0_col25" class="data row0 col25" >1.000</td>
#       <td id="T_1683c_row0_col26" class="data row0 col26" >1.000</td>
#       <td id="T_1683c_row0_col27" class="data row0 col27" >-0.00%</td>
#       <td id="T_1683c_row0_col28" class="data row0 col28" >-0.00%</td>
#       <td id="T_1683c_row0_col29" class="data row0 col29" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_1683c_level0_row1" class="row_heading level0 row1" >QQQ</th>
#       <td id="T_1683c_row1_col0" class="data row1 col0" >100.0%</td>
#       <td id="T_1683c_row1_col1" class="data row1 col1" >-1.70%</td>
#       <td id="T_1683c_row1_col2" class="data row1 col2" >32.54%</td>
#       <td id="T_1683c_row1_col3" class="data row1 col3" >-0.055</td>
#       <td id="T_1683c_row1_col4" class="data row1 col4" >-0.030</td>
#       <td id="T_1683c_row1_col5" class="data row1 col5" >-56.11%</td>
#       <td id="T_1683c_row1_col6" class="data row1 col6" >30.89</td>
#       <td id="T_1683c_row1_col7" class="data row1 col7" >-0.483</td>
#       <td id="T_1683c_row1_col8" class="data row1 col8" >1.84%</td>
#       <td id="T_1683c_row1_col9" class="data row1 col9" >48.20%</td>
#       <td id="T_1683c_row1_col10" class="data row1 col10" >99.1%</td>
#       <td id="T_1683c_row1_col11" class="data row1 col11" >288</td>
#       <td id="T_1683c_row1_col12" class="data row1 col12" >774</td>
#       <td id="T_1683c_row1_col13" class="data row1 col13" >860</td>
#       <td id="T_1683c_row1_col14" class="data row1 col14" >—</td>
#       <td id="T_1683c_row1_col15" class="data row1 col15" >24.91%</td>
#       <td id="T_1683c_row1_col16" class="data row1 col16" >1.785</td>
#       <td id="T_1683c_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_1683c_row1_col18" class="data row1 col18" >-4.32%</td>
#       <td id="T_1683c_row1_col19" class="data row1 col19" >0.754</td>
#       <td id="T_1683c_row1_col20" class="data row1 col20" >0.690</td>
#       <td id="T_1683c_row
# $VOOG: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $SCHG: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $VONG: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
#
# 3 Failed downloads:
# ['VOOG', 'SCHG', 'VONG']: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
#       Period       Start         End
# 0  2005 Bull  2004-12-04  2006-04-08
# <style type="text/css">
# #T_777e9_row0_col1, #T_777e9_row0_col3, #T_777e9_row0_col4, #T_777e9_row0_col7, #T_777e9_row0_col8, #T_777e9_row0_col18, #T_777e9_row0_col19, #T_777e9_row0_col20, #T_777e9_row0_col25, #T_777e9_row0_col27, #T_777e9_row0_col28, #T_777e9_row0_col29, #T_777e9_row1_col2, #T_777e9_row1_col6, #T_777e9_row1_col9, #T_777e9_row1_col10, #T_777e9_row1_col11, #T_777e9_row1_col12, #T_777e9_row1_col13, #T_777e9_row1_col14, #T_777e9_row1_col15, #T_777e9_row1_col16, #T_777e9_row1_col21, #T_777e9_row1_col23, #T_777e9_row1_col24, #T_777e9_row1_col26 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_777e9_row0_col2, #T_777e9_row0_col6, #T_777e9_row0_col9, #T_777e9_row0_col10, #T_777e9_row0_col11, #T_777e9_row0_col12, #T_777e9_row0_col13, #T_777e9_row0_col14, #T_777e9_row0_col15, #T_777e9_row0_col16, #T_777e9_row0_col17, #T_777e9_row0_col21, #T_777e9_row0_col22, #T_777e9_row0_col23, #T_777e9_row0_col24, #T_777e9_row0_col26, #T_777e9_row1_col1, #T_777e9_row1_col3, #T_777e9_row1_col4, #T_777e9_row1_col7, #T_777e9_row1_col8, #T_777e9_row1_col17, #T_777e9_row1_col18, #T_777e9_row1_col19, #T_777e9_row1_col20, #T_777e9_row1_col22, #T_777e9_row1_col25, #T_777e9_row1_col27, #T_777e9_row1_col28, #T_777e9_row1_col29 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_777e9_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_777e9_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# </style>
# <table id="T_777e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_777e9_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_777e9_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_777e9_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_777e9_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_777e9_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_777e9_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_777e9_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_777e9_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_777e9_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_777e9_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_777e9_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_777e9_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_777e9_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_777e9_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_777e9_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_777e9_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_777e9_level0_col16" class="col_heading level0 col16" >RecoveryEfficiency</th>
#       <th id="T_777e9_level0_col17" class="col_heading level0 col17" >RecoveredToPeak_inWindow</th>
#       <th id="T_777e9_level0_col18" class="col_heading level0 col18" >ExpectedShortfall</th>
#       <th id="T_777e9_level0_col19" class="col_heading level0 col19" >ConditionalCorr_Up</th>
#       <th id="T_777e9_level0_col20" class="col_heading level0 col20" >ConditionalCorr_Down</th>
#       <th id="T_777e9_level0_col21" class="col_heading level0 col21" >TrackingError_Ann</th>
#       <th id="T_777e9_level0_col22" class="col_heading level0 col22" >InformationRatio</th>
#       <th id="T_777e9_level0_col23" class="col_heading level0 col23" >UpsideCapture</th>
#       <th id="T_777e9_level0_col24" class="col_heading level0 col24" >DownsideCapture</th>
#       <th id="T_777e9_level0_col25" class="col_heading level0 col25" >PeriodCorr</th>
#       <th id="T_777e9_level0_col26" class="col_heading level0 col26" >PeriodBeta</th>
#       <th id="T_777e9_level0_col27" class="col_heading level0 col27" >PeriodAlpha_per_period</th>
#       <th id="T_777e9_level0_col28" class="col_heading level0 col28" >PeriodAlpha_Ann</th>
#       <th id="T_777e9_level0_col29" class="col_heading level0 col29" >PeriodR2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_777e9_level0_row0" class="row_heading level0 row0" >VTI</th>
#       <td id="T_777e9_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_777e9_row0_col1" class="data row0 col1" >10.59%</td>
#       <td id="T_777e9_row0_col2" class="data row0 col2" >10.13%</td>
#       <td id="T_777e9_row0_col3" class="data row0 col3" >4.436</td>
#       <td id="T_777e9_row0_col4" class="data row0 col4" >1.504</td>
#       <td id="T_777e9_row0_col5" class="data row0 col5" >-7.04%</td>
#       <td id="T_777e9_row0_col6" class="data row0 col6" >2.39</td>
#       <td id="T_777e9_row0_col7" class="data row0 col7" >0.951</td>
#       <td id="T_777e9_row0_col8" class="data row0 col8" >94.08%</td>
#       <td id="T_777e9_row0_col9" class="data row0 col9" >47.29%</td>
#       <td id="T_777e9_row0_col10" class="data row0 col10" >86.1%</td>
#       <td id="T_777e9_row0_col11" class="data row0 col11" >15</td>
#       <td id="T_777e9_row0_col12" class="data row0 col12" >71</td>
#       <td id="T_777e9_row0_col13" class="data row0 col13" >74</td>
#       <td id="T_777e9_row0_col14" class="data row0 col14" >58</td>
#       <td id="T_777e9_row0_col15" class="data row0 col15" >37.32%</td>
#       <td id="T_777e9_row0_col16" class="data row0 col16" >1.076</td>
#       <td id="T_777e9_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_777e9_row0_col18" class="data row0 col18" >-1.33%</td>
#       <td id="T_777e9_row0_col19" class="data row0 col19" >1.000</td>
#       <td id="T_777e9_row0_col20" class="data row0 col20" >1.000</td>
#       <td id="T_777e9_row0_col21" class="data row0 col21" >0.00%</td>
#       <td id="T_777e9_row0_col22" class="data row0 col22" >—</td>
#       <td id="T_777e9_row0_col23" class="data row0 col23" >1.000</td>
#       <td id="T_777e9_row0_col24" class="data row0 col24" >1.000</td>
#       <td id="T_777e9_row0_col25" class="data row0 col25" >1.000</td>
#       <td id="T_777e9_row0_col26" class="data row0 col26" >1.000</td>
#       <td id="T_777e9_row0_col27" class="data row0 col27" >-0.00%</td>
#       <td id="T_777e9_row0_col28" class="data row0 col28" >-0.00%</td>
#       <td id="T_777e9_row0_col29" class="data row0 col29" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_777e9_level0_row1" class="row_heading level0 row1" >QQQ</th>
#       <td id="T_777e9_row1_col0" class="data row1 col0" >100.0%</td>
#       <td id="T_777e9_row1_col1" class="data row1 col1" >4.86%</td>
#       <td id="T_777e9_row1_col2" class="data row1 col2" >13.49%</td>
#       <td id="T_777e9_row1_col3" class="data row1 col3" >0.885</td>
#       <td id="T_777e9_row1_col4" class="data row1 col4" >0.361</td>
#       <td id="T_777e9_row1_col5" class="data row1 col5" >-13.46%</td>
#       <td id="T_777e9_row1_col6" class="data row1 col6" >5.49</td>
#       <td id="T_777e9_row1_col7" class="data row1 col7" >0.839</td>
#       <td id="T_777e9_row1_col8" class="data row1 col8" >60.95%</td>
#       <td id="T_777e9_row1_col9" class="data row1 col9" >49.39%</td>
#       <td id="T_777e9_row1_col10" class="data row1 col10" >92.9%</td>
#       <td id="T_777e9_row1_col11" class="data row1 col11" >45</td>
#       <td id="T_777e9_row1_col12" class="data row1 col12" >130</td>
#       <td id="T_777e9_row1_col13" class="data row1 col13" >158</td>
#       <td id="T_777e9_row1_col14" class="data row1 col14" >104</td>
#       <td id="T_777e9_row1_col15" class="data row1 col15" >41.94%</td>
#       <td id="T_777e9_row1_col16" class="data row1 col16" >1.156</td>
#       <td id="T_777e9_row1_col17" class="data row1 col17" >1</td>
#       <td id="T_777e9_row1_col18" class="data row1 col18" >-1.76%</td>
#       <td id="T_777e9_row1_col19" class="data row1 col19" >0.744</td>
#       <td id="T_777e9_row1_col20" class="data row1 col20" >0.678</td>
#       <td id="T_777e9_row1_col2
# $SCHG: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $VOOG: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $VONG: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
#
# 3 Failed downloads:
# ['SCHG', 'VOOG', 'VONG']: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
#                          Period       Start         End
# 0  2006 Inflation Consolidation  2006-04-08  2006-11-26
# <style type="text/css">
# #T_83272_row0_col1, #T_83272_row0_col3, #T_83272_row0_col4, #T_83272_row0_col7, #T_83272_row0_col8, #T_83272_row0_col14, #T_83272_row0_col18, #T_83272_row0_col19, #T_83272_row0_col20, #T_83272_row0_col25, #T_83272_row0_col27, #T_83272_row0_col28, #T_83272_row0_col29, #T_83272_row1_col2, #T_83272_row1_col6, #T_83272_row1_col9, #T_83272_row1_col10, #T_83272_row1_col11, #T_83272_row1_col12, #T_83272_row1_col13, #T_83272_row1_col15, #T_83272_row1_col16, #T_83272_row1_col21, #T_83272_row1_col23, #T_83272_row1_col24, #T_83272_row1_col26 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_83272_row0_col2, #T_83272_row0_col6, #T_83272_row0_col9, #T_83272_row0_col10, #T_83272_row0_col11, #T_83272_row0_col12, #T_83272_row0_col13, #T_83272_row0_col15, #T_83272_row0_col16, #T_83272_row0_col17, #T_83272_row0_col21, #T_83272_row0_col22, #T_83272_row0_col23, #T_83272_row0_col24, #T_83272_row0_col26, #T_83272_row1_col1, #T_83272_row1_col3, #T_83272_row1_col4, #T_83272_row1_col7, #T_83272_row1_col8, #T_83272_row1_col14, #T_83272_row1_col17, #T_83272_row1_col18, #T_83272_row1_col19, #T_83272_row1_col20, #T_83272_row1_col22, #T_83272_row1_col25, #T_83272_row1_col27, #T_83272_row1_col28, #T_83272_row1_col29 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_83272_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_83272_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# </style>
# <table id="T_83272">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83272_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_83272_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_83272_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_83272_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_83272_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_83272_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_83272_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_83272_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_83272_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_83272_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_83272_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_83272_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_83272_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_83272_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_83272_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_83272_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_83272_level0_col16" class="col_heading level0 col16" >RecoveryEfficiency</th>
#       <th id="T_83272_level0_col17" class="col_heading level0 col17" >RecoveredToPeak_inWindow</th>
#       <th id="T_83272_level0_col18" class="col_heading level0 col18" >ExpectedShortfall</th>
#       <th id="T_83272_level0_col19" class="col_heading level0 col19" >ConditionalCorr_Up</th>
#       <th id="T_83272_level0_col20" class="col_heading level0 col20" >ConditionalCorr_Down</th>
#       <th id="T_83272_level0_col21" class="col_heading level0 col21" >TrackingError_Ann</th>
#       <th id="T_83272_level0_col22" class="col_heading level0 col22" >InformationRatio</th>
#       <th id="T_83272_level0_col23" class="col_heading level0 col23" >UpsideCapture</th>
#       <th id="T_83272_level0_col24" class="col_heading level0 col24" >DownsideCapture</th>
#       <th id="T_83272_level0_col25" class="col_heading level0 col25" >PeriodCorr</th>
#       <th id="T_83272_level0_col26" class="col_heading level0 col26" >PeriodBeta</th>
#       <th id="T_83272_level0_col27" class="col_heading level0 col27" >PeriodAlpha_per_period</th>
#       <th id="T_83272_level0_col28" class="col_heading level0 col28" >PeriodAlpha_Ann</th>
#       <th id="T_83272_level0_col29" class="col_heading level0 col29" >PeriodR2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83272_level0_row0" class="row_heading level0 row0" >VTI</th>
#       <td id="T_83272_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_83272_row0_col1" class="data row0 col1" >13.98%</td>
#       <td id="T_83272_row0_col2" class="data row0 col2" >11.16%</td>
#       <td id="T_83272_row0_col3" class="data row0 col3" >3.853</td>
#       <td id="T_83272_row0_col4" class="data row0 col4" >1.652</td>
#       <td id="T_83272_row0_col5" class="data row0 col5" >-8.46%</td>
#       <td id="T_83272_row0_col6" class="data row0 col6" >3.63</td>
#       <td id="T_83272_row0_col7" class="data row0 col7" >0.954</td>
#       <td id="T_83272_row0_col8" class="data row0 col8" >77.50%</td>
#       <td id="T_83272_row0_col9" class="data row0 col9" >51.90%</td>
#       <td id="T_83272_row0_col10" class="data row0 col10" >83.8%</td>
#       <td id="T_83272_row0_col11" class="data row0 col11" >13</td>
#       <td id="T_83272_row0_col12" class="data row0 col12" >59</td>
#       <td id="T_83272_row0_col13" class="data row0 col13" >97</td>
#       <td id="T_83272_row0_col14" class="data row0 col14" >105</td>
#       <td id="T_83272_row0_col15" class="data row0 col15" >23.63%</td>
#       <td id="T_83272_row0_col16" class="data row0 col16" >1.092</td>
#       <td id="T_83272_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_83272_row0_col18" class="data row0 col18" >-1.49%</td>
#       <td id="T_83272_row0_col19" class="data row0 col19" >1.000</td>
#       <td id="T_83272_row0_col20" class="data row0 col20" >1.000</td>
#       <td id="T_83272_row0_col21" class="data row0 col21" >0.00%</td>
#       <td id="T_83272_row0_col22" class="data row0 col22" >—</td>
#       <td id="T_83272_row0_col23" class="data row0 col23" >1.000</td>
#       <td id="T_83272_row0_col24" class="data row0 col24" >1.000</td>
#       <td id="T_83272_row0_col25" class="data row0 col25" >1.000</td>
#       <td id="T_83272_row0_col26" class="data row0 col26" >1.000</td>
#       <td id="T_83272_row0_col27" class="data row0 col27" >-0.00%</td>
#       <td id="T_83272_row0_col28" class="data row0 col28" >-0.00%</td>
#       <td id="T_83272_row0_col29" class="data row0 col29" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_83272_level0_row1" class="row_heading level0 row1" >QQQ</th>
#       <td id="T_83272_row1_col0" class="data row1 col0" >100.0%</td>
#       <td id="T_83272_row1_col1" class="data row1 col1" >9.43%</td>
#       <td id="T_83272_row1_col2" class="data row1 col2" >16.40%</td>
#       <td id="T_83272_row1_col3" class="data row1 col3" >1.136</td>
#       <td id="T_83272_row1_col4" class="data row1 col4" >0.581</td>
#       <td id="T_83272_row1_col5" class="data row1 col5" >-16.24%</td>
#       <td id="T_83272_row1_col6" class="data row1 col6" >8.30</td>
#       <td id="T_83272_row1_col7" class="data row1 col7" >0.870</td>
#       <td id="T_83272_row1_col8" class="data row1 col8" >40.62%</td>
#       <td id="T_83272_row1_col9" class="data row1 col9" >53.85%</td>
#       <td id="T_83272_row1_col10" class="data row1 col10" >90.6%</td>
#       <td id="T_83272_row1_col11" class="data row1 col11" >29</td>
#       <td id="T_83272_row1_col12" class="data row1 col12" >107</td>
#       <td id="T_83272_row1_col13" class="data row1 col13" >132</td>
#       <td id="T_83272_row1_col14" class="data row1 col14" >97</td>
#       <td id="T_83272_row1_col15" class="data row1 col15" >58.47%</td>
#       <td id="T_83272_row1_col16" class="data row1 col16" >1.194</td>
#       <td id="T_83272_row1_col17" class="data row1 col17" >1</td>
#       <td id="T_83272_row1_col18" class="data row1 col18" >-2.06%</td>
#       <td id="T_83272_row1_col19" class="data row1 col19" >0.810</td>
#       <td id="T_83272_row1_col20" class="data row1 col20" >0.756</td>
#       <td id="T_83272_row1_col2
# $VONG: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $VOOG: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $SCHG: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
#
# 3 Failed downloads:
# ['VONG', 'VOOG', 'SCHG']: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
#       Period       Start         End
# 0  2007 Bull  2006-11-26  2007-06-13
# <style type="text/css">
# #T_41996_row0_col1, #T_41996_row0_col3, #T_41996_row0_col4, #T_41996_row0_col7, #T_41996_row0_col8, #T_41996_row0_col9, #T_41996_row0_col18, #T_41996_row0_col19, #T_41996_row0_col20, #T_41996_row0_col25, #T_41996_row0_col27, #T_41996_row0_col28, #T_41996_row0_col29, #T_41996_row1_col2, #T_41996_row1_col6, #T_41996_row1_col10, #T_41996_row1_col11, #T_41996_row1_col12, #T_41996_row1_col13, #T_41996_row1_col14, #T_41996_row1_col15, #T_41996_row1_col16, #T_41996_row1_col21, #T_41996_row1_col23, #T_41996_row1_col24, #T_41996_row1_col26 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_41996_row0_col2, #T_41996_row0_col6, #T_41996_row0_col10, #T_41996_row0_col11, #T_41996_row0_col12, #T_41996_row0_col13, #T_41996_row0_col14, #T_41996_row0_col15, #T_41996_row0_col16, #T_41996_row0_col17, #T_41996_row0_col21, #T_41996_row0_col22, #T_41996_row0_col23, #T_41996_row0_col24, #T_41996_row0_col26, #T_41996_row1_col1, #T_41996_row1_col3, #T_41996_row1_col4, #T_41996_row1_col7, #T_41996_row1_col8, #T_41996_row1_col9, #T_41996_row1_col17, #T_41996_row1_col18, #T_41996_row1_col19, #T_41996_row1_col20, #T_41996_row1_col22, #T_41996_row1_col25, #T_41996_row1_col27, #T_41996_row1_col28, #T_41996_row1_col29 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_41996_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_41996_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# </style>
# <table id="T_41996">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41996_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_41996_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_41996_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_41996_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_41996_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_41996_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_41996_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_41996_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_41996_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_41996_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_41996_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_41996_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_41996_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_41996_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_41996_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_41996_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_41996_level0_col16" class="col_heading level0 col16" >RecoveryEfficiency</th>
#       <th id="T_41996_level0_col17" class="col_heading level0 col17" >RecoveredToPeak_inWindow</th>
#       <th id="T_41996_level0_col18" class="col_heading level0 col18" >ExpectedShortfall</th>
#       <th id="T_41996_level0_col19" class="col_heading level0 col19" >ConditionalCorr_Up</th>
#       <th id="T_41996_level0_col20" class="col_heading level0 col20" >ConditionalCorr_Down</th>
#       <th id="T_41996_level0_col21" class="col_heading level0 col21" >TrackingError_Ann</th>
#       <th id="T_41996_level0_col22" class="col_heading level0 col22" >InformationRatio</th>
#       <th id="T_41996_level0_col23" class="col_heading level0 col23" >UpsideCapture</th>
#       <th id="T_41996_level0_col24" class="col_heading level0 col24" >DownsideCapture</th>
#       <th id="T_41996_level0_col25" class="col_heading level0 col25" >PeriodCorr</th>
#       <th id="T_41996_level0_col26" class="col_heading level0 col26" >PeriodBeta</th>
#       <th id="T_41996_level0_col27" class="col_heading level0 col27" >PeriodAlpha_per_period</th>
#       <th id="T_41996_level0_col28" class="col_heading level0 col28" >PeriodAlpha_Ann</th>
#       <th id="T_41996_level0_col29" class="col_heading level0 col29" >PeriodR2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41996_level0_row0" class="row_heading level0 row0" >VTI</th>
#       <td id="T_41996_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_41996_row0_col1" class="data row0 col1" >18.06%</td>
#       <td id="T_41996_row0_col2" class="data row0 col2" >11.04%</td>
#       <td id="T_41996_row0_col3" class="data row0 col3" >10.387</td>
#       <td id="T_41996_row0_col4" class="data row0 col4" >2.926</td>
#       <td id="T_41996_row0_col5" class="data row0 col5" >-6.17%</td>
#       <td id="T_41996_row0_col6" class="data row0 col6" >1.74</td>
#       <td id="T_41996_row0_col7" class="data row0 col7" >0.965</td>
#       <td id="T_41996_row0_col8" class="data row0 col8" >97.78%</td>
#       <td id="T_41996_row0_col9" class="data row0 col9" >54.96%</td>
#       <td id="T_41996_row0_col10" class="data row0 col10" >71.9%</td>
#       <td id="T_41996_row0_col11" class="data row0 col11" >7</td>
#       <td id="T_41996_row0_col12" class="data row0 col12" >22</td>
#       <td id="T_41996_row0_col13" class="data row0 col13" >36</td>
#       <td id="T_41996_row0_col14" class="data row0 col14" >42</td>
#       <td id="T_41996_row0_col15" class="data row0 col15" >46.56%</td>
#       <td id="T_41996_row0_col16" class="data row0 col16" >1.066</td>
#       <td id="T_41996_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_41996_row0_col18" class="data row0 col18" >-1.79%</td>
#       <td id="T_41996_row0_col19" class="data row0 col19" >1.000</td>
#       <td id="T_41996_row0_col20" class="data row0 col20" >1.000</td>
#       <td id="T_41996_row0_col21" class="data row0 col21" >0.00%</td>
#       <td id="T_41996_row0_col22" class="data row0 col22" >—</td>
#       <td id="T_41996_row0_col23" class="data row0 col23" >1.000</td>
#       <td id="T_41996_row0_col24" class="data row0 col24" >1.000</td>
#       <td id="T_41996_row0_col25" class="data row0 col25" >1.000</td>
#       <td id="T_41996_row0_col26" class="data row0 col26" >1.000</td>
#       <td id="T_41996_row0_col27" class="data row0 col27" >0.00%</td>
#       <td id="T_41996_row0_col28" class="data row0 col28" >0.00%</td>
#       <td id="T_41996_row0_col29" class="data row0 col29" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_41996_level0_row1" class="row_heading level0 row1" >QQQ</th>
#       <td id="T_41996_row1_col0" class="data row1 col0" >100.0%</td>
#       <td id="T_41996_row1_col1" class="data row1 col1" >13.06%</td>
#       <td id="T_41996_row1_col2" class="data row1 col2" >13.78%</td>
#       <td id="T_41996_row1_col3" class="data row1 col3" >5.002</td>
#       <td id="T_41996_row1_col4" class="data row1 col4" >1.813</td>
#       <td id="T_41996_row1_col5" class="data row1 col5" >-7.20%</td>
#       <td id="T_41996_row1_col6" class="data row1 col6" >2.61</td>
#       <td id="T_41996_row1_col7" class="data row1 col7" >0.929</td>
#       <td id="T_41996_row1_col8" class="data row1 col8" >91.85%</td>
#       <td id="T_41996_row1_col9" class="data row1 col9" >51.94%</td>
#       <td id="T_41996_row1_col10" class="data row1 col10" >79.3%</td>
#       <td id="T_41996_row1_col11" class="data row1 col11" >12</td>
#       <td id="T_41996_row1_col12" class="data row1 col12" >34</td>
#       <td id="T_41996_row1_col13" class="data row1 col13" >39</td>
#       <td id="T_41996_row1_col14" class="data row1 col14" >46</td>
#       <td id="T_41996_row1_col15" class="data row1 col15" >50.58%</td>
#       <td id="T_41996_row1_col16" class="data row1 col16" >1.078</td>
#       <td id="T_41996_row1_col17" class="data row1 col17" >1</td>
#       <td id="T_41996_row1_col18" class="data row1 col18" >-1.96%</td>
#       <td id="T_41996_row1_col19" class="data row1 col19" >0.683</td>
#       <td id="T_41996_row1_col20" class="data row1 col20" >0.843</td>
#       <td id="T_41996_row1_col21" cl
#          Period       Start         End
# 0  GFC Drawdown  2007-06-13  2012-04-26
# <style type="text/css">
# #T_8decb_row0_col1, #T_8decb_row0_col3, #T_8decb_row0_col4, #T_8decb_row0_col7, #T_8decb_row0_col8, #T_8decb_row0_col15, #T_8decb_row0_col17, #T_8decb_row0_col18, #T_8decb_row0_col21, #T_8decb_row0_col27, #T_8decb_row0_col28, #T_8decb_row1_col17, #T_8decb_row1_col20, #T_8decb_row1_col23, #T_8decb_row1_col25, #T_8decb_row1_col29, #T_8decb_row2_col9, #T_8decb_row2_col10, #T_8decb_row2_col11, #T_8decb_row2_col12, #T_8decb_row2_col13, #T_8decb_row2_col14, #T_8decb_row2_col17, #T_8decb_row3_col2, #T_8decb_row3_col6, #T_8decb_row3_col11, #T_8decb_row3_col12, #T_8decb_row3_col13, #T_8decb_row3_col14, #T_8decb_row3_col16, #T_8decb_row3_col17, #T_8decb_row3_col19, #T_8decb_row3_col24, #T_8decb_row3_col26, #T_8decb_row4_col13, #T_8decb_row4_col14, #T_8decb_row4_col17, #T_8decb_row4_col22 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_8decb_row0_col2, #T_8decb_row0_col6, #T_8decb_row0_col10, #T_8decb_row0_col11, #T_8decb_row0_col12, #T_8decb_row0_col13, #T_8decb_row0_col14, #T_8decb_row0_col16, #T_8decb_row0_col19, #T_8decb_row0_col20, #T_8decb_row0_col25, #T_8decb_row0_col29, #T_8decb_row1_col2, #T_8decb_row1_col21, #T_8decb_row1_col22, #T_8decb_row1_col27, #T_8decb_row1_col28, #T_8decb_row3_col1, #T_8decb_row3_col3, #T_8decb_row3_col4, #T_8decb_row3_col7, #T_8decb_row3_col8, #T_8decb_row3_col18, #T_8decb_row4_col9, #T_8decb_row4_col15, #T_8decb_row4_col23, #T_8decb_row4_col24, #T_8decb_row4_col26 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8decb_row0_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# #T_8decb_row0_col9, #T_8decb_row1_col8, #T_8decb_row4_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_8decb_row0_col22 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8decb_row0_col23 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_8decb_row0_col24 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_8decb_row0_col26 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_8decb_row1_col1, #T_8decb_row2_col23 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_8decb_row1_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_8decb_row1_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_8decb_row1_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
#   font-weight: 600;
# }
# #T_8decb_row1_col6 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_8decb_row1_col7 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_8decb_row1_col9 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_8decb_row1_col10 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_8decb_row1_col11 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_8decb_row1_col12, #T_8decb_row3_col23 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_8decb_row1_col13 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_8decb_row1_col14 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_8decb_row1_col15 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_8decb_row1_col16 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_8decb_row1_col18 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_8decb_row1_col19 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_8decb_row1_col24 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_8decb_row1_col26 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_8decb_row2_col1 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col2 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_8decb_row2_col3 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col4, #T_8decb_row2_col18, #T_8decb_row4_col20 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col5 {
#   background-color: #03446a;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_8decb_row2_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_8decb_row2_col7 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col8 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col15 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col16 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_8decb_row2_col19 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_8decb_row2_col20 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col21 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col22 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col24 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_8decb_row2_col25 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_8decb_row2_col26 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_8decb_row2_col27, #T_8decb_row2_col28 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_8decb_row2_col29 {
#   background-color: #b8c6e0;
# ...
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5a8be_row0_col5 {
#   background-color: #034e7b;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_5a8be_row0_col6 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_5a8be_row0_col7 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_5a8be_row0_col8, #T_5a8be_row0_col10, #T_5a8be_row0_col11, #T_5a8be_row0_col12, #T_5a8be_row0_col13, #T_5a8be_row0_col18, #T_5a8be_row0_col19, #T_5a8be_row0_col20, #T_5a8be_row0_col25, #T_5a8be_row0_col29, #T_5a8be_row1_col2, #T_5a8be_row1_col6, #T_5a8be_row1_col7, #T_5a8be_row1_col15, #T_5a8be_row1_col21, #T_5a8be_row1_col23, #T_5a8be_row1_col26, #T_5a8be_row3_col1, #T_5a8be_row3_col3, #T_5a8be_row3_col4, #T_5a8be_row3_col8, #T_5a8be_row3_col16, #T_5a8be_row3_col22, #T_5a8be_row3_col27, #T_5a8be_row3_col28, #T_5a8be_row4_col24 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5a8be_row0_col16 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_5a8be_row0_col22 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_5a8be_row1_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_5a8be_row1_col3 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_5a8be_row1_col4 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_5a8be_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# #T_5a8be_row1_col16 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_5a8be_row1_col18, #T_5a8be_row2_col11, #T_5a8be_row3_col11, #T_5a8be_row4_col11 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_5a8be_row1_col20 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_5a8be_row1_col22, #T_5a8be_row2_col4 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_5a8be_row1_col24 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_5a8be_row1_col27, #T_5a8be_row1_col28 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_5a8be_row2_col2 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_5a8be_row2_col5 {
#   background-color: #adc1dd;
#   color: #000000;
#   font-weight: 600;
# }
# #T_5a8be_row2_col6 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col7 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col8, #T_5a8be_row4_col8 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col10, #T_5a8be_row3_col10, #T_5a8be_row4_col4, #T_5a8be_row4_col10 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_5a8be_row2_col15 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col16 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_5a8be_row2_col18 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_5a8be_row2_col19 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_5a8be_row2_col20 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_5a8be_row2_col21 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col22, #T_5a8be_row4_col29 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_5a8be_row2_col23 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col24 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col25, #T_5a8be_row2_col29 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_5a8be_row2_col26 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_5a8be_row2_col27, #T_5a8be_row2_col28 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_5a8be_row3_col2 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_5a8be_row3_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_5a8be_row3_col15 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_5a8be_row3_col18 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_5a8be_row3_col19 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_5a8be_row3_col20 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_5a8be_row3_col21 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_5a8be_row3_col23 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_5a8be_row3_col24 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_5a8be_row3_col25 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_5a8be_row3_col26 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_5a8be_row3_col29 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_5a8be_row4_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_5a8be_row4_col2, #T_5a8be_row4_col26 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_5a8be_row4_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_5a8be_row4_col5 {
#   background-color: #a5bddb;
#   color: #000000;
#   font-weight: 600;
# }
# #T_5a8be_row4_col6 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_5a8be_row4_col7 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_5a8be_row4_col15 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_5a8be_row4_col19 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_5a8be_row4_col21 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_5a8be_row4_col23 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_5a8be_row4_col25 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_5a8be_row4_col27, #T_5a8be_row4_col28 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# </style>
# <table id="T_5a8be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a8be_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_5a8be_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_5a8be_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_5a8be_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_5a8be_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_5a8be_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_5a8be_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_5a8be_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_5a8be_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_5a8be_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_5a8be_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_5a8be_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_5a8be_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_5a8be_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_5a8be_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_5a8be_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_5a8be_level0_col16" class="col_heading level0 col16" >RecoveryEfficiency</th>
#       <th id="T_5a8be_level0_col17" class="col_heading level0 col17" >RecoveredToPeak_inWindow</th>
#       <th id="T_5a8be_level0_col18" class="col_heading level0 col18" >ExpectedShortfall</th>
#       <th id="T_5a8be_level0_col19" class="col_heading level0 col19" >ConditionalCorr_Up</th>
#       <th id="T_5a8be_level0_col20" class="col_heading lev
#                                        Period       Start    End
# 0  Trump Tariffs Drawdown and AI Bubble Fears  2025-01-19  today
# <style type="text/css">
# #T_34100_row0_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_34100_row0_col2, #T_34100_row0_col6, #T_34100_row0_col10, #T_34100_row0_col11, #T_34100_row0_col12, #T_34100_row0_col15, #T_34100_row0_col16, #T_34100_row0_col17, #T_34100_row0_col21, #T_34100_row0_col23, #T_34100_row0_col24, #T_34100_row0_col26, #T_34100_row1_col13, #T_34100_row1_col14, #T_34100_row1_col17, #T_34100_row2_col9, #T_34100_row2_col17, #T_34100_row3_col13, #T_34100_row3_col14, #T_34100_row3_col17, #T_34100_row3_col18, #T_34100_row3_col19, #T_34100_row3_col20, #T_34100_row3_col25, #T_34100_row3_col29, #T_34100_row4_col1, #T_34100_row4_col3, #T_34100_row4_col4, #T_34100_row4_col7, #T_34100_row4_col8, #T_34100_row4_col17, #T_34100_row4_col18, #T_34100_row4_col22, #T_34100_row4_col27, #T_34100_row4_col28 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_34100_row0_col3, #T_34100_row0_col7, #T_34100_row0_col8, #T_34100_row0_col9, #T_34100_row0_col14, #T_34100_row0_col18, #T_34100_row0_col19, #T_34100_row0_col20, #T_34100_row0_col25, #T_34100_row0_col29, #T_34100_row1_col1, #T_34100_row1_col2, #T_34100_row1_col15, #T_34100_row1_col26, #T_34100_row2_col10, #T_34100_row2_col21, #T_34100_row3_col4, #T_34100_row3_col22, #T_34100_row3_col23, #T_34100_row3_col27, #T_34100_row3_col28, #T_34100_row4_col6, #T_34100_row4_col11, #T_34100_row4_col12, #T_34100_row4_col13, #T_34100_row4_col14, #T_34100_row4_col16, #T_34100_row4_col21, #T_34100_row4_col24 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_34100_row0_col4, #T_34100_row4_col23 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_34100_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_34100_row0_col13 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_34100_row0_col22 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_34100_row0_col27, #T_34100_row0_col28 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_34100_row1_col3 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_34100_row1_col4, #T_34100_row2_col2 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_34100_row1_col5 {
#   background-color: #efe9f3;
#   color: #000000;
#   font-weight: 600;
# }
# #T_34100_row1_col6 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_34100_row1_col7 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_34100_row1_col8 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_34100_row1_col9 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_34100_row1_col10 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_34100_row1_col11 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_34100_row1_col12 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_34100_row1_col16 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_34100_row1_col18 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_34100_row1_col19 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_34100_row1_col20, #T_34100_row4_col19 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_34100_row1_col21 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_34100_row1_col22 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_34100_row1_col23, #T_34100_row2_col15 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_34100_row1_col24 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_34100_row1_col25, #T_34100_row1_col29 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_34100_row1_col27, #T_34100_row1_col28, #T_34100_row2_col16, #T_34100_row4_col26 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_34100_row2_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_34100_row2_col3 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_34100_row2_col4 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_34100_row2_col5 {
#   background-color: #faf3f9;
#   color: #000000;
#   font-weight: 600;
# }
# #T_34100_row2_col6, #T_34100_row2_col26 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_34100_row2_col7 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_34100_row2_col8 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_34100_row2_col11 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_34100_row2_col12 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_34100_row2_col13 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_34100_row2_col14 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_34100_row2_col18 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_34100_row2_col19 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_34100_row2_col20 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_34100_row2_col22, #T_34100_row2_col27, #T_34100_row2_col28 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_34100_row2_col23 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_34100_row2_col24, #T_34100_row3_col2 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_34100_row2_col25, #T_34100_row2_col29 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_34100_row3_col1 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_34100_row3_col3 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_34100_row3_col5 {
#   background-color: #cdd0e5;
#   color: #000000;
#   font-weight: 600;
# }
# #T_34100_row3_col6 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_34100_row3_col7 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_34100_row3_col8 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_34100_row3_col9 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_34100_row3_col10 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_34100_row3_col11 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_34100_row3_col12 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_34100_row3_col15 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_34100_row3_col16 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_34100_row3_col21, #T_34100_row4_col2 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_34100_row3_col24 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_34100_row3_col26 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_34100_row4_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# #T_34100_row4_col9 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_34100_row4_col10 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_34100_row4_col15 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_34100_row4_col20 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_34100_row4_col25, #T_34100_row4_col29 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_34100">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34100_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_34100_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_34100_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_34100_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_34100_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_34100_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_34100_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_34100_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_34100_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_34100_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_34100_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_34100_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_34100_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_34100_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_34100_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_34100_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_34100_level0_col16
# done
