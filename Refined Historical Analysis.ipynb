# %%
from __future__ import annotations

from dataclasses import dataclass
from typing import Dict, Iterable, Optional, Tuple, Union, List

import numpy as np
import pandas as pd
import yfinance as yf

# Optional: pretty display in notebooks
try:
    from IPython.display import display
except Exception:  # pragma: no cover
    display = None


def _as_datetime(x):
    if x is None:
        return None
    return pd.to_datetime(x)


def _fetch_prices(
    tickers,
    start: str,
    end: str | None,
    auto_adjust: bool = True,
) -> pd.DataFrame:
    """
    Robust price fetcher for yfinance across:
      - single vs multiple tickers
      - MultiIndex ticker/field ordering
      - auto_adjust True/False

    Returns a DataFrame with columns = tickers, values = adjusted close series.
    """
    tickers = list(tickers)

    df = yf.download(
        tickers=tickers,
        start=start,
        end=end,
        auto_adjust=auto_adjust,
        progress=False,
        group_by="ticker",
        threads=True,
    )

    if df is None or df.empty:
        return pd.DataFrame()

    # Decide which field we want
    # auto_adjust=True => "Close" is already adjusted
    wanted = "Close" if auto_adjust else "Adj Close"

    # --------
    # MultiIndex case
    # --------
    if isinstance(df.columns, pd.MultiIndex):
        lvl0 = df.columns.get_level_values(0)
        lvl1 = df.columns.get_level_values(1)

        # Case A: (ticker, field)
        if wanted in set(lvl1):
            px = df.xs(wanted, level=1, axis=1)
        # Case B: (field, ticker)
        elif wanted in set(lvl0):
            px = df.xs(wanted, level=0, axis=1)
        else:
            # Fallback: try Close then Adj Close
            for alt in ["Close", "Adj Close"]:
                if alt in set(lvl1):
                    px = df.xs(alt, level=1, axis=1)
                    break
                if alt in set(lvl0):
                    px = df.xs(alt, level=0, axis=1)
                    break
            else:
                raise KeyError(f"Could not find Close/Adj Close in columns: {df.columns}")

        px = px.copy()
        px.columns = [c.upper() for c in px.columns]  # normalize
        return px.dropna(how="all")

    # --------
    # Single-ticker (flat columns) case
    # --------
    if wanted in df.columns:
        s = df[wanted].copy()
    elif (not auto_adjust) and ("Close" in df.columns):
        # fallback if Adj Close missing
        s = df["Close"].copy()
    else:
        raise KeyError(f"Could not find '{wanted}' (or fallback) in columns: {df.columns.tolist()}")

    # If single ticker, return as DataFrame with that ticker name
    name = tickers[0].upper() if len(tickers) == 1 else "PRICE"
    return pd.DataFrame({name: s}).dropna(how="all")


def _returns(prices: pd.Series) -> pd.Series:
    r = prices.pct_change().replace([np.inf, -np.inf], np.nan)
    return r.dropna()


def _max_drawdown(prices: pd.Series) -> float:
    peak = prices.cummax()
    dd = prices / peak - 1.0
    return float(dd.min())


def _drawdown_series(prices: pd.Series) -> pd.Series:
    peak = prices.cummax()
    dd = prices / peak - 1.0
    return dd


def _ulcer_index(prices: pd.Series) -> float:
    dd = _drawdown_series(prices)
    # ulcer index uses drawdown in percent; square, average, sqrt
    dd_pct = (dd * 100.0).clip(upper=0)
    ui = float(np.sqrt(np.mean(np.square(dd_pct.values))))
    return ui


def _cagr(prices: pd.Series) -> float:
    if prices.shape[0] < 2:
        return np.nan
    start_val = float(prices.iloc[0])
    end_val = float(prices.iloc[-1])
    if start_val <= 0 or end_val <= 0:
        return np.nan
    days = (prices.index[-1] - prices.index[0]).days
    if days <= 0:
        return np.nan
    years = days / 365.25
    return float((end_val / start_val) ** (1 / years) - 1)


def _ann_vol(returns: pd.Series, periods_per_year: int = 252) -> float:
    if len(returns) < 2:
        return np.nan
    return float(returns.std(ddof=1) * np.sqrt(periods_per_year))


def _martin_ratio(prices: pd.Series, rf: float = 0.0) -> float:
    # Martin = (annualized return - rf)) / Ulcer Index
    ui = _ulcer_index(prices)
    if ui == 0 or np.isnan(ui):
        return np.nan
    ann = _cagr(prices)
    return float((ann - rf) / (ui / 100.0))  # ui was percent-based


def _time_underwater_stats(prices: pd.Series) -> Tuple[float, float, float, float]:
    """
    Returns:
      pct_days_underwater, avg_underwater_days, p95_underwater_days, max_underwater_days
    Underwater = price < prior peak.
    """
    if prices.shape[0] < 2:
        return (np.nan, np.nan, np.nan, np.nan)

    peak = prices.cummax()
    underwater = prices < peak

    # Identify contiguous underwater runs
    runs = []
    in_run = False
    run_start = None

    for dt, uw in underwater.items():
        if uw and not in_run:
            in_run = True
            run_start = dt
        elif (not uw) and in_run:
            # run ends at previous date; count business days in slice
            in_run = False
            run_end = dt
            # count rows between run_start and the day before run_end
            run_len = prices.loc[run_start:run_end].shape[0] - 1
            runs.append(max(run_len, 1))
            run_start = None

    if in_run and run_start is not None:
        run_len = prices.loc[run_start:].shape[0]
        runs.append(max(run_len, 1))

    pct = float(underwater.mean())
    if len(runs) == 0:
        return (pct, 0.0, 0.0, 0.0)

    runs_arr = np.array(runs, dtype=float)
    return (
        pct,
        float(np.mean(runs_arr)),
        float(np.percentile(runs_arr, 95)),
        float(np.max(runs_arr)),
    )


def _recovery_metrics(prices: pd.Series) -> Tuple[float, float, float, float]:
    """
    Period-local recovery notion:
      - Find the maximum drawdown peak->trough in the window.
      - Define "recovery" as trough -> reclaim that peak.
      Outputs:
        ttr_days, recovery_slope_annualized, recovery_efficiency, did_recover(0/1)
    """
    if prices.shape[0] < 5:
        return (np.nan, np.nan, np.nan, 0.0)

    peak = prices.cummax()
    dd = prices / peak - 1.0

    # Locate trough of worst drawdown
    trough_dt = dd.idxmin()
    trough_price = float(prices.loc[trough_dt])

    # Peak before trough that defines this drawdown
    pre = prices.loc[:trough_dt]
    if pre.shape[0] < 2:
        return (np.nan, np.nan, np.nan, 0.0)

    peak_dt = pre.idxmax()
    peak_price = float(prices.loc[peak_dt])

    if peak_price <= 0 or trough_price <= 0:
        return (np.nan, np.nan, np.nan, 0.0)

    max_dd = float((trough_price / peak_price) - 1.0)  # negative

    # Find first date after trough that reaches prior peak
    post = prices.loc[trough_dt:]
    recovered = post[post >= peak_price]
    if recovered.empty:
        # No recovery to old peak within window
        # Still can compute "slope" to end of window as partial recovery
        end_price = float(prices.iloc[-1])
        days = max((prices.index[-1] - trough_dt).days, 1)
        daily_slope = float(np.log(end_price / trough_price) / days) if end_price > 0 else np.nan
        ann_slope = float(np.exp(daily_slope * 252) - 1) if not np.isnan(daily_slope) else np.nan
        # Efficiency: partial return / abs(dd)
        partial_return = float((end_price / trough_price) - 1.0)
        eff = float(partial_return / abs(max_dd)) if max_dd != 0 else np.nan
        return (np.nan, ann_slope, eff, 0.0)

    rec_dt = recovered.index[0]
    ttr_days = max((rec_dt - trough_dt).days, 1)

    # log slope from trough to recovered peak
    daily_slope = float(np.log(peak_price / trough_price) / ttr_days)
    ann_slope = float(np.exp(daily_slope * 252) - 1)
    # recovery return from trough to peak
    rec_return = float((peak_price / trough_price) - 1.0)
    eff = float(rec_return / abs(max_dd)) if max_dd != 0 else np.nan
    return (float(ttr_days), ann_slope, eff, 1.0)


def _capital_efficiency_index(cagr: float, max_dd: float) -> float:
    """
    Capital Efficiency: CAGR / |MaxDD|
    Higher = better returns per unit of drawdown risk
    """
    if np.isnan(cagr) or np.isnan(max_dd) or max_dd >= 0:
        return np.nan
    return float(cagr / abs(max_dd))


def _volatility_drag_ratio(prices: pd.Series, returns: pd.Series) -> float:
    """
    Volatility Drag: geometric mean / arithmetic mean
    Ratio of actual compounded return to simple average return.
    Lower drag (closer to 1.0) is better.
    """
    if len(returns) < 2:
        return np.nan
    
    # Arithmetic mean return
    arith_mean = float(returns.mean())
    
    # Geometric mean: (ending / starting) ^ (1/n) - 1
    if prices.iloc[0] <= 0 or prices.iloc[-1] <= 0:
        return np.nan
    
    total_return = float(prices.iloc[-1] / prices.iloc[0]) - 1.0
    n_periods = len(returns)
    geom_mean = float((1 + total_return) ** (1 / n_periods) - 1)
    
    if arith_mean == 0:
        return np.nan
    return float(geom_mean / arith_mean)


def _pct_time_near_highs(prices: pd.Series, threshold_pct: float = 0.05) -> float:
    """
    % Time Near Highs: Percentage of days within threshold_pct of rolling peak
    threshold_pct: e.g., 0.05 for within 5% of peak
    """
    if prices.shape[0] < 2:
        return np.nan
    
    peak = prices.cummax()
    pct_below = (prices / peak - 1.0)  # negative values = below peak
    near_high = pct_below >= -threshold_pct
    
    return float(near_high.mean())


def _trend_persistence(returns: pd.Series) -> float:
    """
    Trend Persistence: % of days where return has same sign as previous day
    Higher = stronger momentum/trend, Lower = more mean reversion
    """
    if len(returns) < 2:
        return np.nan
    
    sign_change = np.sign(returns.values[:-1]) == np.sign(returns.values[1:])
    # Only count where neither is zero
    valid = (returns.values[:-1] != 0) & (returns.values[1:] != 0)
    
    if valid.sum() == 0:
        return np.nan
    
    return float(sign_change[valid].mean())


def _expected_shortfall(returns: pd.Series, percentile: float = 5.0) -> float:
    """
    Expected Shortfall (CVaR): Average of worst X% of returns
    percentile: e.g., 5.0 for worst 5%
    """
    if len(returns) < 10:
        return np.nan
    
    threshold = np.percentile(returns.values, percentile)
    worst = returns[returns <= threshold]
    
    if len(worst) == 0:
        return np.nan
    
    return float(worst.mean())


def _capture_ratio(etf_prices: pd.Series, bench_prices: pd.Series, side: str) -> float:
    """
    Upside/Downside capture within window:
      - Uses daily returns
      - For upside: only days benchmark return > 0
      - For downside: only days benchmark return < 0
      Ratio of compounded returns over those selected days
    """
    etf_r = _returns(etf_prices)
    bmk_r = _returns(bench_prices)

    aligned = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()
    
    if aligned.empty:
        return np.nan

    if side == "up":
        sel = aligned[aligned["bmk"] > 0]
    elif side == "down":
        sel = aligned[aligned["bmk"] < 0]
    else:
        raise ValueError("side must be 'up' or 'down'")

    if sel.empty:
        return np.nan

    etf_comp = float(np.prod(1.0 + sel["etf"].values) - 1.0)
    bmk_comp = float(np.prod(1.0 + sel["bmk"].values) - 1.0)
    if bmk_comp == 0:
        return np.nan
    return float(etf_comp / bmk_comp)


# --- Helper to normalize period values ---
def _normalize_period(val: Union[Tuple[str, Optional[str]], List[Optional[str]]]) -> Tuple[str, Optional[str]]:
    """
    Accepts period value as:
      - [start, end]
      - [start, None]
      - [start, end, trough]  (third element ignored)
    Returns (start, end) with end possibly None.
    """
    if isinstance(val, (list, tuple)):
        if len(val) >= 2:
            return val[0], val[1]
        raise ValueError("Period value must have at least [start, end_or_None]")
    raise ValueError(f"Unsupported period value type: {type(val)}")


def _period_metrics_for_series(
    etf_prices: pd.Series,
    bench_prices: Optional[pd.Series] = None,
    rf: float = 0.0,
) -> Dict[str, float]:
    r = _returns(etf_prices)

    maxdd = _max_drawdown(etf_prices)
    ui = _ulcer_index(etf_prices)
    cagr = _cagr(etf_prices)
    vol = _ann_vol(r)
    martin = _martin_ratio(etf_prices, rf=rf)

    pct_uw, avg_uw, p95_uw, max_uw = _time_underwater_stats(etf_prices)
    ttr, rec_slope, rec_eff, did_rec = _recovery_metrics(etf_prices)

    # New metrics
    cap_eff = _capital_efficiency_index(cagr, maxdd)
    vol_drag = _volatility_drag_ratio(etf_prices, r)
    pct_near_highs = _pct_time_near_highs(etf_prices)
    trend_pers = _trend_persistence(r)
    cvar = _expected_shortfall(r)

    # Period-level relative metrics (not rolling - calculated over full period)
    periods_per_year = 252
    period_corr = np.nan
    period_beta = np.nan
    period_alpha_per = np.nan
    period_r2 = np.nan
    te_ann = np.nan
    ir = np.nan
    cond_corr_up = np.nan
    cond_corr_down = np.nan
    period_alpha_ann = np.nan

    if bench_prices is not None:
        bmk_r = _returns(bench_prices)
        # Align returns
        aligned = pd.concat([r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()
        if len(aligned) >= 10:  # Need minimum data points
            etf_r = aligned["etf"]
            bmk_r = aligned["bmk"]
            
            # Full period correlation
            period_corr = float(etf_r.corr(bmk_r))
            
            # Full period beta/alpha/R2 using simple linear regression
            # beta = cov(etf, bmk) / var(bmk)
            cov_xy = etf_r.cov(bmk_r)
            var_x = bmk_r.var()
            
            if var_x > 0:
                period_beta = float(cov_xy / var_x)
                # alpha = mean(etf) - beta * mean(bmk)
                period_alpha_per = float(etf_r.mean() - period_beta * bmk_r.mean())
                # R² = correlation²
                period_r2 = float(period_corr ** 2)
                
                # Annualized alpha (simple scaling - for daily returns)
                period_alpha_ann = float(period_alpha_per * periods_per_year)
                
                # Tracking error: std(etf - bmk) annualized
                active_returns = etf_r - bmk_r
                te_ann = float(active_returns.std(ddof=1) * np.sqrt(periods_per_year))
                
                # Information ratio: annualized_alpha / tracking_error
                if te_ann > 0:
                    ir = float(period_alpha_ann / te_ann)
            
            # Conditional correlations (full period)
            # Correlation when benchmark is up
            up_mask = bmk_r > 0
            if up_mask.sum() >= 10:
                cond_corr_up = float(etf_r[up_mask].corr(bmk_r[up_mask]))
            
            # Correlation when benchmark is down
            down_mask = bmk_r < 0
            if down_mask.sum() >= 10:
                cond_corr_down = float(etf_r[down_mask].corr(bmk_r[down_mask]))

    out = {
        "CAGR": cagr,
        "AnnVol": vol,
        "MaxDD": maxdd,
        "UlcerIndex": ui,
        "Martin": martin,
        "CapitalEfficiency": cap_eff,
        "VolatilityDrag": vol_drag,
        "PctTimeNearHighs": pct_near_highs,
        "TrendPersistence": trend_pers,
        "ExpectedShortfall": cvar,
        "PctDaysUnderwater": pct_uw,
        "AvgUnderwaterDays": avg_uw,
        "P95UnderwaterDays": p95_uw,
        "MaxUnderwaterDays": max_uw,
        "TTR_Days": ttr,
        "RecoverySlope_Ann": rec_slope,
        "RecoveryEfficiency": rec_eff,
        "RecoveredToPeak_inWindow": did_rec,
        # Period-level relative metrics (vs benchmark)
        "PeriodCorr": period_corr,
        "PeriodBeta": period_beta,
        "PeriodAlpha_per_period": period_alpha_per,
        "PeriodAlpha_Ann": period_alpha_ann,
        "PeriodR2": period_r2,
        "TrackingError_Ann": te_ann,
        "InformationRatio": ir,
        "ConditionalCorr_Up": cond_corr_up,
        "ConditionalCorr_Down": cond_corr_down,
    }

    if bench_prices is not None:
        out["UpsideCapture"] = _capture_ratio(etf_prices, bench_prices, "up")
        out["DownsideCapture"] = _capture_ratio(etf_prices, bench_prices, "down")

    return out


def _format_styler(df: pd.DataFrame) -> "pd.io.formats.style.Styler":
    pct_cols = [c for c in df.columns if c in {
        "CAGR", "AnnVol", "MaxDD", "PctTimeNearHighs", "TrendPersistence",
        "RecoverySlope_Ann", "PeriodAlpha_per_period", "PeriodAlpha_Ann", "TrackingError_Ann"
    }]
    ratio_cols = [c for c in df.columns if "Capture" in c or c in {
        "Martin", "RecoveryEfficiency", "CapitalEfficiency", "VolatilityDrag",
        "InformationRatio", "PeriodR2"
    }]
    corr_beta_cols = [c for c in df.columns if c in {
        "PeriodCorr", "ConditionalCorr_Up", "ConditionalCorr_Down", "PeriodBeta"
    }]
    num_cols = [c for c in df.columns if c not in pct_cols + ratio_cols + corr_beta_cols]

    sty = df.style

    # Formats
    fmt = {c: "{:.2%}" for c in pct_cols}
    fmt.update({c: "{:.3f}" for c in ratio_cols})
    fmt.update({c: "{:.3f}" for c in corr_beta_cols})
    fmt.update({c: "{:.2f}" for c in num_cols if c not in fmt})

    # Special-case some columns
    if "UlcerIndex" in df.columns:
        fmt["UlcerIndex"] = "{:.2f}"
    if "PctDaysUnderwater" in df.columns:
        fmt["PctDaysUnderwater"] = "{:.1%}"
    if "ExpectedShortfall" in df.columns:
        fmt["ExpectedShortfall"] = "{:.2%}"
    for c in ["AvgUnderwaterDays", "P95UnderwaterDays", "MaxUnderwaterDays", "TTR_Days"]:
        if c in df.columns:
            fmt[c] = "{:.0f}"
    if "RecoveredToPeak_inWindow" in df.columns:
        fmt["RecoveredToPeak_inWindow"] = "{:.0f}"
    
    # Add DataAvailability column formatting
    if "DataAvailability" in df.columns:
        fmt["DataAvailability"] = "{:.1%}"

    sty = sty.format(fmt, na_rep="—")

    # Only apply gradient to columns that have at least one non-NaN value
    gradient_cols = []
    for c in df.columns:
        if c != "DataAvailability" and df[c].notna().any():
            gradient_cols.append(c)
    
    if gradient_cols:
        sty = sty.background_gradient(subset=gradient_cols)

    if "MaxDD" in df.columns:
        sty = sty.map(lambda v: "font-weight:600" if pd.notna(v) and v < 0 else "", subset=["MaxDD"])

    return sty


def analyze_regimes(
    tickers: Union[str, Iterable[str]],
    periods: Dict[str, Union[Tuple[str, Optional[str]], List[Optional[str]]]],
    benchmark: Optional[str] = "VTI",
    rf: float = 0.0,
    auto_adjust: bool = True,
    display_results: bool = True,
) -> Dict[str, pd.DataFrame]:
    """
    Analyze ETF behavior over multiple named time windows.

    periods: dict mapping name -> [start, end] or [start, end, trough].
    The third element (trough) is ignored; only start/end are used.

    **KEY FEATURE**: Handles ETFs with different inception dates by:
    - Using whatever data is available within each period
    - Adding a "DataAvailability" column showing % of period covered
    - Computing metrics based on the actual overlapping dates

    Usage:
      analyze_regimes(["QQQ","SPY","USMV"], periods=periods_dict, benchmark="VTI")

    Args:
      tickers: one ticker or list of tickers to analyze
      periods: dict mapping name -> (start, end). end can be None to mean "today"
      benchmark: benchmark ticker for upside/downside capture (None disables)
      rf: risk-free rate used in Martin ratio (annual, e.g. 0.02)
      auto_adjust: pass through to yfinance download
      display_results: if True and in IPython, displays styled tables

    Returns:
      dict mapping period name -> DataFrame (rows=tickers, cols=metrics + DataAvailability)
    """
    if isinstance(tickers, str):
        tick_list = [tickers]
    else:
        tick_list = list(tickers)

    results: Dict[str, pd.DataFrame] = {}

    for pname, pval in periods.items():
        # Normalize period value to (start, end)
        pstart, pend = _normalize_period(pval)

        pstart_dt = _as_datetime(pstart)
        pend_dt = _as_datetime(pend)

        if pstart_dt is None:
            raise ValueError(f"Period '{pname}' missing start date.")
        if pend_dt is not None and pend_dt <= pstart_dt:
            raise ValueError(f"Period '{pname}' has end <= start.")

        # Fetch prices for ETFs + benchmark in one call when possible
        fetch_list = tick_list.copy()
        bmk = None
        if benchmark:
            fetch_list = sorted(set(fetch_list + [benchmark]))
            bmk = benchmark

        # Fetch with wider date range to capture all possible data
        px = _fetch_prices(
            fetch_list, 
            start=str(pstart_dt.date()), 
            end=(None if pend_dt is None else str(pend_dt.date())), 
            auto_adjust=auto_adjust
        )

        if px.empty:
            continue

        # Calculate full period trading days for availability calculation
        full_period_end = pend_dt if pend_dt is not None else px.index.max()
        full_period_mask = (px.index >= pstart_dt) & (px.index <= full_period_end)
        full_period_days = full_period_mask.sum()

        rows = []
        idx = []

        bench_series = px[bmk].dropna() if (bmk and bmk in px.columns) else None

        for t in tick_list:
            if t not in px.columns:
                continue
            
            # Get ticker series and filter to period
            s_full = px[t].dropna()
            
            # Find actual overlap with requested period
            s = s_full.loc[pstart_dt: full_period_end]
            
            if len(s) < 10:  # Need minimum data for meaningful analysis
                continue
            
            # Calculate data availability
            actual_days = len(s)
            data_availability = actual_days / full_period_days if full_period_days > 0 else 0.0
            
            # Get benchmark data aligned to ETF dates
            b = None
            if bench_series is not None:
                b = bench_series.reindex(s.index).dropna()
                # Re-align s to b to ensure matching dates
                if len(b) > 0:
                    common_idx = s.index.intersection(b.index)
                    s = s.loc[common_idx]
                    b = b.loc[common_idx]

            if len(s) < 10:
                continue

            metrics = _period_metrics_for_series(
                s, 
                bench_prices=b if b is not None else None, 
                rf=rf
            )
            
            # Add data availability to metrics
            metrics["DataAvailability"] = data_availability
            
            rows.append(metrics)
            idx.append(t)

        if not rows:
            continue

        df = pd.DataFrame(rows, index=idx)

        # Sort columns with DataAvailability first
        col_order = [
            "DataAvailability",  # Show this first so users know coverage
            "CAGR", "AnnVol", "Martin", "CapitalEfficiency",
            "MaxDD", "UlcerIndex",
            "VolatilityDrag", "PctTimeNearHighs", "TrendPersistence",
            "PctDaysUnderwater", "AvgUnderwaterDays", "P95UnderwaterDays", "MaxUnderwaterDays",
            "TTR_Days", "RecoverySlope_Ann", "RecoveryEfficiency", "RecoveredToPeak_inWindow",
            "ExpectedShortfall",
            # Rolling analytics
            "RollingCorr", "ConditionalCorr_Up", "ConditionalCorr_Down",
            "RollingBeta", "RollingR2",
            "RollingAlpha_per_period", "RollingAlpha_Ann",
            "TrackingError_Ann", "InformationRatio",
            # Capture
            "UpsideCapture", "DownsideCapture",
        ]
        df = df[[c for c in col_order if c in df.columns] + [c for c in df.columns if c not in col_order]]

        results[pname] = df

        if display_results and display is not None:
            title = pd.DataFrame({
                "Period": [pname], 
                "Start": [str(pstart_dt.date())], 
                "End": [("today" if pend_dt is None else str(full_period_end.date()))]
            })
            display(title)
            display(_format_styler(df))

    return results


# -------------------------
# Rolling analytics helpers
# -------------------------
def _to_returns(px: pd.Series, freq: str = "D") -> pd.Series:
    """
    Convert price series to returns.
    freq:
      - "D": daily returns
      - "W": weekly returns (Fri close)
      - "M": monthly returns
    """
    px = px.dropna()
    if freq == "D":
        r = px.pct_change()
    elif freq == "W":
        r = px.resample("W-FRI").last().pct_change()
    elif freq == "M":
        r = px.resample("M").last().pct_change()
    else:
        raise ValueError("freq must be one of {'D','W','M'}")
    return r.replace([np.inf, -np.inf], np.nan).dropna()


def rolling_corr(etf_r: pd.Series, bmk_r: pd.Series, window: int) -> pd.Series:
    df = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()
    return df["etf"].rolling(window).corr(df["bmk"])


def rolling_beta_alpha(etf_r: pd.Series, bmk_r: pd.Series, window: int) -> pd.DataFrame:
    """
    OLS in each rolling window:
      etf = alpha + beta*bmk + eps

    Returns DataFrame columns: ['alpha', 'beta', 'r2']
    alpha is per-period (daily/weekly/monthly) alpha, NOT annualized.
    """
    df = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()

    # Rolling means
    mx = df["bmk"].rolling(window).mean()
    my = df["etf"].rolling(window).mean()

    # Rolling cov/var
    cov_xy = df["bmk"].rolling(window).cov(df["etf"])
    var_x  = df["bmk"].rolling(window).var()

    beta = cov_xy / var_x
    alpha = my - beta * mx

    # Rolling R^2: correlation squared is simpler and more stable
    corr = df["etf"].rolling(window).corr(df["bmk"])
    r2 = corr ** 2

    out = pd.DataFrame({"alpha": alpha, "beta": beta, "r2": r2})
    return out


def annualize_alpha(alpha_per_period: pd.Series, periods_per_year: int) -> pd.Series:
    """
    Convert per-period alpha (e.g., daily) into annualized additive approximation.
    For small alpha this is fine. If you prefer compounding, use exp/log.
    """
    return alpha_per_period * periods_per_year


def tracking_error(etf_r: pd.Series, bmk_r: pd.Series, window: int, periods_per_year: int) -> pd.Series:
    """
    Rolling annualized tracking error: std(etf - bmk) * sqrt(periods_per_year)
    """
    df = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()
    active = (df["etf"] - df["bmk"])
    return active.rolling(window).std(ddof=1) * np.sqrt(periods_per_year)


def information_ratio(
    alpha_per_period: pd.Series,
    te_annualized: pd.Series,
    periods_per_year: int
) -> pd.Series:
    """
    Rolling Information Ratio:
      IR = annualized_alpha / annualized_tracking_error
    alpha_per_period should align with te_annualized index.
    """
    ann_alpha = annualize_alpha(alpha_per_period, periods_per_year)
    return ann_alpha / te_annualized.replace(0, np.nan)


def conditional_corr(
    etf_r: pd.Series,
    bmk_r: pd.Series,
    window: int,
    condition: str = "down"
) -> pd.Series:
    """
    Rolling correlation computed only on observations inside each window
    where benchmark return is <0 (down) or >0 (up).

    Note: This is more expensive than plain rolling corr because the set
    of points changes per window. For typical ETF daily data it's fine.
    """
    df = pd.concat([etf_r.rename("etf"), bmk_r.rename("bmk")], axis=1).dropna()

    def _corr_in_window(idx: pd.Index) -> float:
        x = df.loc[idx]
        if condition == "down":
            sub = x[x["bmk"] < 0]
        elif condition == "up":
            sub = x[x["bmk"] > 0]
        else:
            raise ValueError("condition must be 'down' or 'up'")
        if len(sub) < max(10, window // 5):  # require some minimum points
            return np.nan
        return float(sub["etf"].corr(sub["bmk"]))

    # Apply rolling to one column, use its index to get full DataFrame slice
    return df["etf"].rolling(window).apply(lambda w: _corr_in_window(w.index), raw=False)

# %%
periods = {
    "Full History": [
      "2023-08-01",
      None
    ],
    "DotCom Bubble Drawdown": [
      "2001-06-02",
      "2004-12-04",
      "2002-10-09"
    ],
    "2005 Bull": [
      "2004-12-04",
      "2006-04-08"
    ],
    "2006 Inflation Consolidation": [
      "2006-04-08",
      "2006-11-26",
      "2006-06-13"
    ],
    "2007 Bull": [
      "2006-11-26",
      "2007-06-13"
    ],
    "GFC Drawdown": [
      "2007-06-13",
      "2012-04-26",
      "2009-03-09"
    ],
    "Eurozone Consolidation": [
      "2012-03-02",
      "2012-10-14",
      "2012-06-04"
    ],
    "2012–2015 Bull": [
      "2012-10-14",
      "2015-05-23"
    ],
    "2015-2016 Selloff Drawdown": [
      "2015-05-23",
      "2016-09-15",
      "2016-02-11"
    ],
    "2016-2017 Bull": [
      "2016-09-15",
      "2017-12-26"
    ],
    "Volmageddon Drawdown": [
      "2017-12-26",
      "2019-05-23",
      "2018-12-24"
    ],
    "2019-2020 Bull": [
      "2019-05-23",
      "2020-01-19"
    ],
    "Covid Drawdown": [
      "2020-01-19",
      "2020-09-28",
      "2020-03-23"
    ],
    "Leadership Rotation Consolidation": [
      "2020-08-02",
      "2020-12-27",
      "2020-09-23"
    ],
    "2021 Bull": [
      "2020-12-27",
      "2021-12-03"
    ],
    "2022 Rate Hike Drawdown": [
      "2021-12-03",
      "2024-03-02",
      "2022-10-12"
    ],
    "2024 Bull": [
      "2024-03-02",
      "2024-06-16"
    ],
    "2024 Consolidation": [
      "2024-06-16",
      "2024-12-06",
      "2024-08-05"
    ],
    "2025 Transition Bull": [
      "2024-12-06",
      "2025-01-19"
    ],
    "Trump Tariffs Drawdown and AI Bubble Fears": [
      "2025-01-19",
      None,
      "2025-04-08"
    ]
  }

# %%
ticker_list = ["VTI", "AVUV", "VXUS", "AVDV", "AVDE", "AVEM", "EMGF", "AVES", 'IMTM', "IDMO", "EEMO", "VWO", "AVEE", "IDYN", "JIRE", 'DFAX', 'AVNM']

# %%
analyze_regimes(ticker_list, periods=periods, benchmark="VTI", rf=0.0)
print("done")
# Out:
#          Period       Start    End
# 0  Full History  2023-08-01  today
# <style type="text/css">
# #T_6c2b5_row0_col1, #T_6c2b5_row6_col2, #T_6c2b5_row12_col27, #T_6c2b5_row12_col28 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_6c2b5_row0_col2, #T_6c2b5_row16_col15 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_6c2b5_row0_col3, #T_6c2b5_row15_col3, #T_6c2b5_row15_col24, #T_6c2b5_row16_col4 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_6c2b5_row0_col4, #T_6c2b5_row6_col4, #T_6c2b5_row6_col15, #T_6c2b5_row11_col19, #T_6c2b5_row11_col20, #T_6c2b5_row12_col24 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_6c2b5_row0_col5 {
#   background-color: #9ab8d8;
#   color: #000000;
#   font-weight: 600;
# }
# #T_6c2b5_row0_col6, #T_6c2b5_row4_col25, #T_6c2b5_row6_col9, #T_6c2b5_row13_col29, #T_6c2b5_row16_col19 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_6c2b5_row0_col7 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_6c2b5_row0_col8, #T_6c2b5_row2_col21 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_6c2b5_row0_col9, #T_6c2b5_row1_col19, #T_6c2b5_row4_col9, #T_6c2b5_row8_col9, #T_6c2b5_row8_col24, #T_6c2b5_row10_col18, #T_6c2b5_row11_col2, #T_6c2b5_row15_col25 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_6c2b5_row0_col10, #T_6c2b5_row4_col29 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_6c2b5_row0_col11, #T_6c2b5_row3_col24, #T_6c2b5_row7_col25, #T_6c2b5_row7_col26, #T_6c2b5_row9_col11, #T_6c2b5_row10_col23 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_6c2b5_row0_col12 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_6c2b5_row0_col13, #T_6c2b5_row8_col6 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_6c2b5_row0_col14, #T_6c2b5_row4_col16, #T_6c2b5_row10_col24 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_6c2b5_row0_col15, #T_6c2b5_row14_col12 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_6c2b5_row0_col16 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_6c2b5_row0_col17, #T_6c2b5_row0_col21, #T_6c2b5_row1_col1, #T_6c2b5_row1_col3, #T_6c2b5_row1_col4, #T_6c2b5_row1_col7, #T_6c2b5_row1_col8, #T_6c2b5_row1_col15, #T_6c2b5_row1_col17, #T_6c2b5_row1_col18, #T_6c2b5_row1_col22, #T_6c2b5_row1_col27, #T_6c2b5_row1_col28, #T_6c2b5_row2_col17, #T_6c2b5_row3_col17, #T_6c2b5_row4_col17, #T_6c2b5_row5_col17, #T_6c2b5_row6_col17, #T_6c2b5_row7_col17, #T_6c2b5_row7_col23, #T_6c2b5_row8_col17, #T_6c2b5_row9_col14, #T_6c2b5_row9_col17, #T_6c2b5_row10_col17, #T_6c2b5_row11_col17, #T_6c2b5_row12_col9, #T_6c2b5_row12_col17, #T_6c2b5_row12_col19, #T_6c2b5_row12_col20, #T_6c2b5_row12_col25, #T_6c2b5_row12_col26, #T_6c2b5_row12_col29, #T_6c2b5_row13_col2, #T_6c2b5_row13_col6, #T_6c2b5_row13_col10, #T_6c2b5_row13_col11, #T_6c2b5_row13_col12, #T_6c2b5_row13_col13, #T_6c2b5_row13_col16, #T_6c2b5_row13_col17, #T_6c2b5_row13_col24, #T_6c2b5_row14_col17, #T_6c2b5_row15_col17, #T_6c2b5_row16_col17 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6c2b5_row0_col18, #T_6c2b5_row12_col6 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_6c2b5_row0_col19, #T_6c2b5_row0_col20, #T_6c2b5_row0_col25, #T_6c2b5_row0_col29, #T_6c2b5_row1_col2, #T_6c2b5_row1_col6, #T_6c2b5_row1_col10, #T_6c2b5_row1_col11, #T_6c2b5_row1_col12, #T_6c2b5_row1_col13, #T_6c2b5_row1_col14, #T_6c2b5_row1_col16, #T_6c2b5_row1_col23, #T_6c2b5_row1_col24, #T_6c2b5_row1_col26, #T_6c2b5_row2_col9, #T_6c2b5_row3_col27, #T_6c2b5_row3_col28, #T_6c2b5_row9_col15, #T_6c2b5_row12_col21, #T_6c2b5_row13_col1, #T_6c2b5_row13_col3, #T_6c2b5_row13_col4, #T_6c2b5_row13_col7, #T_6c2b5_row13_col8, #T_6c2b5_row13_col18, #T_6c2b5_row13_col22 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6c2b5_row0_col22 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_6c2b5_row0_col23, #T_6c2b5_row0_col24 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_6c2b5_row0_col26, #T_6c2b5_row9_col7 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_6c2b5_row0_col27, #T_6c2b5_row0_col28, #T_6c2b5_row1_col25, #T_6c2b5_row11_col11, #T_6c2b5_row12_col8 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_6c2b5_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# #T_6c2b5_row1_col9, #T_6c2b5_row16_col6 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_6c2b5_row1_col20, #T_6c2b5_row10_col14, #T_6c2b5_row16_col10 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_6c2b5_row1_col21 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_6c2b5_row1_col29, #T_6c2b5_row2_col29, #T_6c2b5_row7_col2, #T_6c2b5_row9_col26 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_6c2b5_row2_col1, #T_6c2b5_row14_col24 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_6c2b5_row2_col2, #T_6c2b5_row5_col15 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_6c2b5_row2_col3, #T_6c2b5_row2_col4, #T_6c2b5_row4_col26 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_6c2b5_row2_col5 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_6c2b5_row2_col6, #T_6c2b5_row9_col29, #T_6c2b5_row14_col19, #T_6c2b5_row16_col16 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_6c2b5_row2_col7, #T_6c2b5_row3_col22, #T_6c2b5_row4_col21, #T_6c2b5_row8_col7 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_6c2b5_row2_col8, #T_6c2b5_row11_col7, #T_6c2b5_row15_col27, #T_6c2b5_row15_col28 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_6c2b5_row2_col10, #T_6c2b5_row8_col10, #T_6c2b5_row10_col7, #T_6c2b5_row15_col10 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_6c2b5_row2_col11, #T_6c2b5_row6_col19, #T_6c2b5_row15_col11, #T_6c2b5_row16_col11 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_6c2b5_row2_col12, #T_6c2b5_row11_col29 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_6c2b5_row2_col13, #T_6c2b5_row2_col15, #T_6c2b5_row12_col2, #T_6c2b5_row15_col13 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_6c2b5_row2_col14, #T_6c2b5_row7_col29, #T_6c2b5_row15_col14, #T_6c2b5_row16_col14 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_6c2b5_row2_col16, #T_6c2b5_row15_col6 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_6c2b5_row2_col18, #T_6c2b5_row16_col21 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_6c2b5_row2_col19, #T_6c2b5_row9_col3 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_6c2b5_row2_col20, #T_6c2b5_row5_col12, #T_6c2b5_row9_col4, #T_6c2b5_row10_col27, #T_6c2b5_row10_col28 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_6c2b5_row2_col22 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_6c2b5_row2_col23, #T_6c2b5_row6_col20, #T_6c2b5_row7_col15 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_6c2b5_row2_col24, #T_6c2b5_row9_col20 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_6c2b5_row2_col25 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_6c2b5_row2_col26, #T_6c2b5_row4_col24 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_6c2b5_row2_col27, #T_6c2b5_row2_col28 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_6c2b5_row3_col1, #T_6c2b5_row11_col10, #T_6c2b5_row16_col8 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_6c2b5_row3_col2 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_6c2b5_row3_col3, #T_6c2b5_row8_col23, #T_6c2b5_row15_col16 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_6c2b5_row3_col4, #T_6c2b5_row3_col6, #T_6c2b5_row4_col2, #T_6c2b5_row10_col19, #T_6c2b5_row15_col20, #T_6c2b5_row16_col20 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_6c2b5_row3_col5 {
#   background-color: #3790c0;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_6c2b5_row3_col7 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_6c2b5_row3_col8, #T_6c2b5_row8_col27, #T_6c2b5_row8_col28 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_6c2b5_row3_col9 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_6c2b5_row3_col10, #T_6c2b5_row8_col25 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_6c2b5_row3_col11, #T_6c2b5_row12_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_6c2b5_row3_col12, #T_6c2b5_row7_col3, #T_6c2b5_row7_col4, #T_6c2b5_row7_col24, #T_6c2b5_row8_col11, #T_6c2b5_row11_c
# $AVNM: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $AVEE: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $VWO: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $AVUV: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $VXUS: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $AVEM: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $IDYN: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $IMTM: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $EMGF: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $EEMO: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $DFAX: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $IDMO: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $AVDE: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $AVES: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $AVDV: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
# $JIRE: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
#
# 16 Failed downloads:
# ['AVNM', 'AVEE', 'VWO', 'AVUV', 'VXUS', 'AVEM', 'IDYN', 'IMTM', 'EMGF', 'EEMO', 'DFAX', 'IDMO', 'AVDE', 'AVES', 'AVDV', 'JIRE']: possibly delisted; no price data found  (1d 2001-06-02 -> 2004-12-04) (Yahoo error = "Data doesn't exist for startDate = 991454400, endDate = 1102136400")
#                    Period       Start         End
# 0  DotCom Bubble Drawdown  2001-06-02  2004-12-04
# <style type="text/css">
# #T_bdcb0_row0_col1, #T_bdcb0_row0_col2, #T_bdcb0_row0_col3, #T_bdcb0_row0_col4, #T_bdcb0_row0_col6, #T_bdcb0_row0_col7, #T_bdcb0_row0_col8, #T_bdcb0_row0_col9, #T_bdcb0_row0_col10, #T_bdcb0_row0_col11, #T_bdcb0_row0_col12, #T_bdcb0_row0_col13, #T_bdcb0_row0_col14, #T_bdcb0_row0_col15, #T_bdcb0_row0_col16, #T_bdcb0_row0_col17, #T_bdcb0_row0_col18, #T_bdcb0_row0_col19, #T_bdcb0_row0_col20, #T_bdcb0_row0_col21, #T_bdcb0_row0_col23, #T_bdcb0_row0_col24, #T_bdcb0_row0_col25, #T_bdcb0_row0_col26, #T_bdcb0_row0_col27, #T_bdcb0_row0_col28, #T_bdcb0_row0_col29 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bdcb0_row0_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# </style>
# <table id="T_bdcb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdcb0_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_bdcb0_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_bdcb0_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_bdcb0_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_bdcb0_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_bdcb0_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_bdcb0_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_bdcb0_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_bdcb0_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_bdcb0_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_bdcb0_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_bdcb0_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_bdcb0_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_bdcb0_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_bdcb0_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_bdcb0_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_bdcb0_level0_col16" class="col_heading level0 col16" >RecoveryEfficiency</th>
#       <th id="T_bdcb0_level0_col17" class="col_heading level0 col17" >RecoveredToPeak_inWindow</th>
#       <th id="T_bdcb0_level0_col18" class="col_heading level0 col18" >ExpectedShortfall</th>
#       <th id="T_bdcb0_level0_col19" class="col_heading level0 col19" >ConditionalCorr_Up</th>
#       <th id="T_bdcb0_level0_col20" class="col_heading level0 col20" >ConditionalCorr_Down</th>
#       <th id="T_bdcb0_level0_col21" class="col_heading level0 col21" >TrackingError_Ann</th>
#       <th id="T_bdcb0_level0_col22" class="col_heading level0 col22" >InformationRatio</th>
#       <th id="T_bdcb0_level0_col23" class="col_heading level0 col23" >UpsideCapture</th>
#       <th id="T_bdcb0_level0_col24" class="col_heading level0 col24" >DownsideCapture</th>
#       <th id="T_bdcb0_level0_col25" class="col_heading level0 col25" >PeriodCorr</th>
#       <th id="T_bdcb0_level0_col26" class="col_heading level0 col26" >PeriodBeta</th>
#       <th id="T_bdcb0_level0_col27" class="col_heading level0 col27" >PeriodAlpha_per_period</th>
#       <th id="T_bdcb0_level0_col28" class="col_heading level0 col28" >PeriodAlpha_Ann</th>
#       <th id="T_bdcb0_level0_col29" class="col_heading level0 col29" >PeriodR2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdcb0_level0_row0" class="row_heading level0 row0" >VTI</th>
#       <td id="T_bdcb0_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_bdcb0_row0_col1" class="data row0 col1" >2.72%</td>
#       <td id="T_bdcb0_row0_col2" class="data row0 col2" >18.96%</td>
#       <td id="T_bdcb0_row0_col3" class="data row0 col3" >0.182</td>
#       <td id="T_bdcb0_row0_col4" class="data row0 col4" >0.078</td>
#       <td id="T_bdcb0_row0_col5" class="data row0 col5" >-34.66%</td>
#       <td id="T_bdcb0_row0_col6" class="data row0 col6" >14.93</td>
#       <td id="T_bdcb0_row0_col7" class="data row0 col7" >0.600</td>
#       <td id="T_bdcb0_row0_col8" class="data row0 col8" >30.42%</td>
#       <td id="T_bdcb0_row0_col9" class="data row0 col9" >47.50%</td>
#       <td id="T_bdcb0_row0_col10" class="data row0 col10" >97.4%</td>
#       <td id="T_bdcb0_row0_col11" class="data row0 col11" >65</td>
#       <td id="T_bdcb0_row0_col12" class="data row0 col12" >355</td>
#       <td id="T_bdcb0_row0_col13" class="data row0 col13" >635</td>
#       <td id="T_bdcb0_row0_col14" class="data row0 col14" >463</td>
#       <td id="T_bdcb0_row0_col15" class="data row0 col15" >26.06%</td>
#       <td id="T_bdcb0_row0_col16" class="data row0 col16" >1.530</td>
#       <td id="T_bdcb0_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_bdcb0_row0_col18" class="data row0 col18" >-2.55%</td>
#       <td id="T_bdcb0_row0_col19" class="data row0 col19" >1.000</td>
#       <td id="T_bdcb0_row0_col20" class="data row0 col20" >1.000</td>
#       <td id="T_bdcb0_row0_col21" class="data row0 col21" >0.00%</td>
#       <td id="T_bdcb0_row0_col22" class="data row0 col22" >—</td>
#       <td id="T_bdcb0_row0_col23" class="data row0 col23" >1.000</td>
#       <td id="T_bdcb0_row0_col24" class="data row0 col24" >1.000</td>
#       <td id="T_bdcb0_row0_col25" class="data row0 col25" >1.000</td>
#       <td id="T_bdcb0_row0_col26" class="data row0 col26" >1.000</td>
#       <td id="T_bdcb0_row0_col27" class="data row0 col27" >-0.00%</td>
#       <td id="T_bdcb0_row0_col28" class="data row0 col28" >-0.00%</td>
#       <td id="T_bdcb0_row0_col29" class="data row0 col29" >1.000</td>
#     </tr>
#   </tbody>
# </table>
# $EMGF: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $AVDV: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $JIRE: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $DFAX: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $IDMO: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $IMTM: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $IDYN: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $AVUV: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $EEMO: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $AVEE: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $VXUS: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $AVEM: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $AVNM: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $AVDE: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
# $AVES: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
#
# 15 Failed downloads:
# ['EMGF', 'AVDV', 'JIRE', 'DFAX', 'IDMO', 'IMTM', 'IDYN', 'AVUV', 'EEMO', 'AVEE', 'VXUS', 'AVEM', 'AVNM', 'AVDE', 'AVES']: possibly delisted; no price data found  (1d 2004-12-04 -> 2006-04-08) (Yahoo error = "Data doesn't exist for startDate = 1102136400, endDate = 1144468800")
#       Period       Start         End
# 0  2005 Bull  2004-12-04  2006-04-08
# <style type="text/css">
# #T_f1e76_row0_col1, #T_f1e76_row0_col2, #T_f1e76_row0_col3, #T_f1e76_row0_col4, #T_f1e76_row0_col6, #T_f1e76_row0_col9, #T_f1e76_row0_col13, #T_f1e76_row0_col15, #T_f1e76_row0_col16, #T_f1e76_row0_col17, #T_f1e76_row0_col21, #T_f1e76_row0_col22, #T_f1e76_row0_col23, #T_f1e76_row0_col24, #T_f1e76_row0_col26, #T_f1e76_row0_col27, #T_f1e76_row0_col28, #T_f1e76_row1_col7, #T_f1e76_row1_col8, #T_f1e76_row1_col10, #T_f1e76_row1_col11, #T_f1e76_row1_col12, #T_f1e76_row1_col14, #T_f1e76_row1_col17, #T_f1e76_row1_col18, #T_f1e76_row1_col19, #T_f1e76_row1_col20, #T_f1e76_row1_col22, #T_f1e76_row1_col25, #T_f1e76_row1_col29 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f1e76_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_f1e76_row0_col7, #T_f1e76_row0_col8, #T_f1e76_row0_col10, #T_f1e76_row0_col11, #T_f1e76_row0_col12, #T_f1e76_row0_col14, #T_f1e76_row0_col18, #T_f1e76_row0_col19, #T_f1e76_row0_col20, #T_f1e76_row0_col25, #T_f1e76_row0_col29, #T_f1e76_row1_col1, #T_f1e76_row1_col2, #T_f1e76_row1_col3, #T_f1e76_row1_col4, #T_f1e76_row1_col6, #T_f1e76_row1_col9, #T_f1e76_row1_col13, #T_f1e76_row1_col15, #T_f1e76_row1_col16, #T_f1e76_row1_col21, #T_f1e76_row1_col23, #T_f1e76_row1_col24, #T_f1e76_row1_col26, #T_f1e76_row1_col27, #T_f1e76_row1_col28 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f1e76_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# </style>
# <table id="T_f1e76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1e76_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_f1e76_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_f1e76_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_f1e76_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_f1e76_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_f1e76_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_f1e76_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_f1e76_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_f1e76_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_f1e76_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_f1e76_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_f1e76_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_f1e76_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_f1e76_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_f1e76_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_f1e76_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_f1e76_level0_col16" class="col_heading level0 col16" >RecoveryEfficiency</th>
#       <th id="T_f1e76_level0_col17" class="col_heading level0 col17" >RecoveredToPeak_inWindow</th>
#       <th id="T_f1e76_level0_col18" class="col_heading level0 col18" >ExpectedShortfall</th>
#       <th id="T_f1e76_level0_col19" class="col_heading level0 col19" >ConditionalCorr_Up</th>
#       <th id="T_f1e76_level0_col20" class="col_heading level0 col20" >ConditionalCorr_Down</th>
#       <th id="T_f1e76_level0_col21" class="col_heading level0 col21" >TrackingError_Ann</th>
#       <th id="T_f1e76_level0_col22" class="col_heading level0 col22" >InformationRatio</th>
#       <th id="T_f1e76_level0_col23" class="col_heading level0 col23" >UpsideCapture</th>
#       <th id="T_f1e76_level0_col24" class="col_heading level0 col24" >DownsideCapture</th>
#       <th id="T_f1e76_level0_col25" class="col_heading level0 col25" >PeriodCorr</th>
#       <th id="T_f1e76_level0_col26" class="col_heading level0 col26" >PeriodBeta</th>
#       <th id="T_f1e76_level0_col27" class="col_heading level0 col27" >PeriodAlpha_per_period</th>
#       <th id="T_f1e76_level0_col28" class="col_heading level0 col28" >PeriodAlpha_Ann</th>
#       <th id="T_f1e76_level0_col29" class="col_heading level0 col29" >PeriodR2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1e76_level0_row0" class="row_heading level0 row0" >VTI</th>
#       <td id="T_f1e76_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_f1e76_row0_col1" class="data row0 col1" >10.59%</td>
#       <td id="T_f1e76_row0_col2" class="data row0 col2" >10.13%</td>
#       <td id="T_f1e76_row0_col3" class="data row0 col3" >4.436</td>
#       <td id="T_f1e76_row0_col4" class="data row0 col4" >1.504</td>
#       <td id="T_f1e76_row0_col5" class="data row0 col5" >-7.04%</td>
#       <td id="T_f1e76_row0_col6" class="data row0 col6" >2.39</td>
#       <td id="T_f1e76_row0_col7" class="data row0 col7" >0.951</td>
#       <td id="T_f1e76_row0_col8" class="data row0 col8" >94.08%</td>
#       <td id="T_f1e76_row0_col9" class="data row0 col9" >47.29%</td>
#       <td id="T_f1e76_row0_col10" class="data row0 col10" >86.1%</td>
#       <td id="T_f1e76_row0_col11" class="data row0 col11" >15</td>
#       <td id="T_f1e76_row0_col12" class="data row0 col12" >71</td>
#       <td id="T_f1e76_row0_col13" class="data row0 col13" >74</td>
#       <td id="T_f1e76_row0_col14" class="data row0 col14" >58</td>
#       <td id="T_f1e76_row0_col15" class="data row0 col15" >37.32%</td>
#       <td id="T_f1e76_row0_col16" class="data row0 col16" >1.076</td>
#       <td id="T_f1e76_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_f1e76_row0_col18" class="data row0 col18" >-1.33%</td>
#       <td id="T_f1e76_row0_col19" class="data row0 col19" >1.000</td>
#       <td id="T_f1e76_row0_col20" class="data row0 col20" >1.000</td>
#       <td id="T_f1e76_row0_col21" class="data row0 col21" >0.00%</td>
#       <td id="T_f1e76_row0_col22" class="data row0 col22" >—</td>
#       <td id="T_f1e76_row0_col23" class="data row0 col23" >1.000</td>
#       <td id="T_f1e76_row0_col24" class="data row0 col24" >1.000</td>
#       <td id="T_f1e76_row0_col25" class="data row0 col25" >1.000</td>
#       <td id="T_f1e76_row0_col26" class="data row0 col26" >1.000</td>
#       <td id="T_f1e76_row0_col27" class="data row0 col27" >0.00%</td>
#       <td id="T_f1e76_row0_col28" class="data row0 col28" >0.00%</td>
#       <td id="T_f1e76_row0_col29" class="data row0 col29" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_f1e76_level0_row1" class="row_heading level0 row1" >VWO</th>
#       <td id="T_f1e76_row1_col0" class="data row1 col0" >80.8%</td>
#       <td id="T_f1e76_row1_col1" class="data row1 col1" >37.28%</td>
#       <td id="T_f1e76_row1_col2" class="data row1 col2" >19.28%</td>
#       <td id="T_f1e76_row1_col3" class="data row1 col3" >9.811</td>
#       <td id="T_f1e76_row1_col4" class="data row1 col4" >3.389</td>
#       <td id="T_f1e76_row1_col5" class="data row1 col5" >-11.00%</td>
#       <td id="T_f1e76_row1_col6" class="data row1 col6" >3.80</td>
#       <td id="T_f1e76_row1_col7" class="data row1 col7" >0.945</td>
#       <td id="T_f1e76_row1_col8" class="data row1 col8" >78.02%</td>
#       <td id="T_f1e76_row1_col9" class="data row1 col9" >49.07%</td>
#       <td id="T_f1e76_row1_col10" class="data row1 col10" >81.7%</td>
#       <td id="T_f1e76_row1_col11" class="data row1 col11" >10</td>
#       <td id="T_f1e76_row1_col12" class="data row1 col12" >40</td>
#       <td id="T_f1e76_row1_col13" class="data row1 col13" >83</td>
#       <td id="T_f1e76_row1_col14" class="data row1 col14" >29</td>
#       <td id="T_f1e76_row1_col15" class="data row1 col15" >175.32%</td>
#       <td id="T_f1e76_row1_col16" class="data row1 col16" >1.124</td>
#       <td id="T_f1e76_row1_col17" class="data row1 col17" >1</td>
#       <td id="T_f1e76_row1_col18" class="data row1 col18" >-2.54%</td>
#       <td id="T_f1e76_row1_col19" class="data row1 col19" >0.559</td>
#       <td id="T_f1e76_row1_col20" class="data row1 col20" >0.542</td>
#       <td id="T_f1e76_row1_col21" c
# $IDMO: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $JIRE: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $AVDE: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $AVEM: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $DFAX: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $EMGF: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $AVNM: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $VXUS: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $AVEE: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $IDYN: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $AVES: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $EEMO: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $AVUV: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $AVDV: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
# $IMTM: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
#
# 15 Failed downloads:
# ['IDMO', 'JIRE', 'AVDE', 'AVEM', 'DFAX', 'EMGF', 'AVNM', 'VXUS', 'AVEE', 'IDYN', 'AVES', 'EEMO', 'AVUV', 'AVDV', 'IMTM']: possibly delisted; no price data found  (1d 2006-04-08 -> 2006-11-26) (Yahoo error = "Data doesn't exist for startDate = 1144468800, endDate = 1164517200")
#                          Period       Start         End
# 0  2006 Inflation Consolidation  2006-04-08  2006-11-26
# <style type="text/css">
# #T_43728_row0_col1, #T_43728_row0_col3, #T_43728_row0_col4, #T_43728_row0_col7, #T_43728_row0_col8, #T_43728_row0_col9, #T_43728_row0_col17, #T_43728_row0_col18, #T_43728_row0_col19, #T_43728_row0_col20, #T_43728_row0_col25, #T_43728_row0_col27, #T_43728_row0_col28, #T_43728_row0_col29, #T_43728_row1_col2, #T_43728_row1_col6, #T_43728_row1_col10, #T_43728_row1_col11, #T_43728_row1_col12, #T_43728_row1_col13, #T_43728_row1_col15, #T_43728_row1_col16, #T_43728_row1_col21, #T_43728_row1_col23, #T_43728_row1_col24, #T_43728_row1_col26 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_43728_row0_col2, #T_43728_row0_col6, #T_43728_row0_col10, #T_43728_row0_col11, #T_43728_row0_col12, #T_43728_row0_col13, #T_43728_row0_col14, #T_43728_row0_col15, #T_43728_row0_col16, #T_43728_row0_col21, #T_43728_row0_col22, #T_43728_row0_col23, #T_43728_row0_col24, #T_43728_row0_col26, #T_43728_row1_col1, #T_43728_row1_col3, #T_43728_row1_col4, #T_43728_row1_col7, #T_43728_row1_col8, #T_43728_row1_col9, #T_43728_row1_col14, #T_43728_row1_col17, #T_43728_row1_col18, #T_43728_row1_col19, #T_43728_row1_col20, #T_43728_row1_col22, #T_43728_row1_col25, #T_43728_row1_col27, #T_43728_row1_col28, #T_43728_row1_col29 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_43728_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_43728_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# </style>
# <table id="T_43728">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43728_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_43728_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_43728_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_43728_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_43728_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_43728_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_43728_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_43728_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_43728_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_43728_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_43728_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_43728_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_43728_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_43728_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_43728_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_43728_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_43728_level0_col16" class="col_heading level0 col16" >RecoveryEfficiency</th>
#       <th id="T_43728_level0_col17" class="col_heading level0 col17" >RecoveredToPeak_inWindow</th>
#       <th id="T_43728_level0_col18" class="col_heading level0 col18" >ExpectedShortfall</th>
#       <th id="T_43728_level0_col19" class="col_heading level0 col19" >ConditionalCorr_Up</th>
#       <th id="T_43728_level0_col20" class="col_heading level0 col20" >ConditionalCorr_Down</th>
#       <th id="T_43728_level0_col21" class="col_heading level0 col21" >TrackingError_Ann</th>
#       <th id="T_43728_level0_col22" class="col_heading level0 col22" >InformationRatio</th>
#       <th id="T_43728_level0_col23" class="col_heading level0 col23" >UpsideCapture</th>
#       <th id="T_43728_level0_col24" class="col_heading level0 col24" >DownsideCapture</th>
#       <th id="T_43728_level0_col25" class="col_heading level0 col25" >PeriodCorr</th>
#       <th id="T_43728_level0_col26" class="col_heading level0 col26" >PeriodBeta</th>
#       <th id="T_43728_level0_col27" class="col_heading level0 col27" >PeriodAlpha_per_period</th>
#       <th id="T_43728_level0_col28" class="col_heading level0 col28" >PeriodAlpha_Ann</th>
#       <th id="T_43728_level0_col29" class="col_heading level0 col29" >PeriodR2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43728_level0_row0" class="row_heading level0 row0" >VTI</th>
#       <td id="T_43728_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_43728_row0_col1" class="data row0 col1" >13.98%</td>
#       <td id="T_43728_row0_col2" class="data row0 col2" >11.16%</td>
#       <td id="T_43728_row0_col3" class="data row0 col3" >3.853</td>
#       <td id="T_43728_row0_col4" class="data row0 col4" >1.652</td>
#       <td id="T_43728_row0_col5" class="data row0 col5" >-8.46%</td>
#       <td id="T_43728_row0_col6" class="data row0 col6" >3.63</td>
#       <td id="T_43728_row0_col7" class="data row0 col7" >0.954</td>
#       <td id="T_43728_row0_col8" class="data row0 col8" >77.50%</td>
#       <td id="T_43728_row0_col9" class="data row0 col9" >51.90%</td>
#       <td id="T_43728_row0_col10" class="data row0 col10" >83.8%</td>
#       <td id="T_43728_row0_col11" class="data row0 col11" >13</td>
#       <td id="T_43728_row0_col12" class="data row0 col12" >59</td>
#       <td id="T_43728_row0_col13" class="data row0 col13" >97</td>
#       <td id="T_43728_row0_col14" class="data row0 col14" >105</td>
#       <td id="T_43728_row0_col15" class="data row0 col15" >23.63%</td>
#       <td id="T_43728_row0_col16" class="data row0 col16" >1.092</td>
#       <td id="T_43728_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_43728_row0_col18" class="data row0 col18" >-1.49%</td>
#       <td id="T_43728_row0_col19" class="data row0 col19" >1.000</td>
#       <td id="T_43728_row0_col20" class="data row0 col20" >1.000</td>
#       <td id="T_43728_row0_col21" class="data row0 col21" >0.00%</td>
#       <td id="T_43728_row0_col22" class="data row0 col22" >—</td>
#       <td id="T_43728_row0_col23" class="data row0 col23" >1.000</td>
#       <td id="T_43728_row0_col24" class="data row0 col24" >1.000</td>
#       <td id="T_43728_row0_col25" class="data row0 col25" >1.000</td>
#       <td id="T_43728_row0_col26" class="data row0 col26" >1.000</td>
#       <td id="T_43728_row0_col27" class="data row0 col27" >-0.00%</td>
#       <td id="T_43728_row0_col28" class="data row0 col28" >-0.00%</td>
#       <td id="T_43728_row0_col29" class="data row0 col29" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_43728_level0_row1" class="row_heading level0 row1" >VWO</th>
#       <td id="T_43728_row1_col0" class="data row1 col0" >100.0%</td>
#       <td id="T_43728_row1_col1" class="data row1 col1" >13.32%</td>
#       <td id="T_43728_row1_col2" class="data row1 col2" >27.32%</td>
#       <td id="T_43728_row1_col3" class="data row1 col3" >1.042</td>
#       <td id="T_43728_row1_col4" class="data row1 col4" >0.513</td>
#       <td id="T_43728_row1_col5" class="data row1 col5" >-25.99%</td>
#       <td id="T_43728_row1_col6" class="data row1 col6" >12.78</td>
#       <td id="T_43728_row1_col7" class="data row1 col7" >0.769</td>
#       <td id="T_43728_row1_col8" class="data row1 col8" >23.12%</td>
#       <td id="T_43728_row1_col9" class="data row1 col9" >50.00%</td>
#       <td id="T_43728_row1_col10" class="data row1 col10" >91.9%</td>
#       <td id="T_43728_row1_col11" class="data row1 col11" >29</td>
#       <td id="T_43728_row1_col12" class="data row1 col12" >112</td>
#       <td id="T_43728_row1_col13" class="data row1 col13" >139</td>
#       <td id="T_43728_row1_col14" class="data row1 col14" >—</td>
#       <td id="T_43728_row1_col15" class="data row1 col15" >54.79%</td>
#       <td id="T_43728_row1_col16" class="data row1 col16" >1.266</td>
#       <td id="T_43728_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_43728_row1_col18" class="data row1 col18" >-3.88%</td>
#       <td id="T_43728_row1_col19" class="data row1 col19" >0.811</td>
#       <td id="T_43728_row1_col20" class="data row1 col20" >0.724</td>
#       <td id="T_43728_row1_col
# $AVNM: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $AVDE: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $JIRE: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $IDYN: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $AVDV: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $IDMO: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $EEMO: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $AVEM: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $IMTM: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $DFAX: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $EMGF: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $AVUV: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $AVEE: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $VXUS: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
# $AVES: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
#
# 15 Failed downloads:
# ['AVNM', 'AVDE', 'JIRE', 'IDYN', 'AVDV', 'IDMO', 'EEMO', 'AVEM', 'IMTM', 'DFAX', 'EMGF', 'AVUV', 'AVEE', 'VXUS', 'AVES']: possibly delisted; no price data found  (1d 2006-11-26 -> 2007-06-13) (Yahoo error = "Data doesn't exist for startDate = 1164517200, endDate = 1181707200")
#       Period       Start         End
# 0  2007 Bull  2006-11-26  2007-06-13
# <style type="text/css">
# #T_8ebad_row0_col1, #T_8ebad_row0_col2, #T_8ebad_row0_col3, #T_8ebad_row0_col4, #T_8ebad_row0_col6, #T_8ebad_row0_col10, #T_8ebad_row0_col15, #T_8ebad_row0_col16, #T_8ebad_row0_col17, #T_8ebad_row0_col21, #T_8ebad_row0_col22, #T_8ebad_row0_col23, #T_8ebad_row0_col24, #T_8ebad_row0_col26, #T_8ebad_row0_col27, #T_8ebad_row0_col28, #T_8ebad_row1_col7, #T_8ebad_row1_col8, #T_8ebad_row1_col9, #T_8ebad_row1_col11, #T_8ebad_row1_col12, #T_8ebad_row1_col13, #T_8ebad_row1_col14, #T_8ebad_row1_col17, #T_8ebad_row1_col18, #T_8ebad_row1_col19, #T_8ebad_row1_col20, #T_8ebad_row1_col22, #T_8ebad_row1_col25, #T_8ebad_row1_col29 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_8ebad_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_8ebad_row0_col7, #T_8ebad_row0_col8, #T_8ebad_row0_col9, #T_8ebad_row0_col11, #T_8ebad_row0_col12, #T_8ebad_row0_col13, #T_8ebad_row0_col14, #T_8ebad_row0_col18, #T_8ebad_row0_col19, #T_8ebad_row0_col20, #T_8ebad_row0_col25, #T_8ebad_row0_col29, #T_8ebad_row1_col1, #T_8ebad_row1_col2, #T_8ebad_row1_col3, #T_8ebad_row1_col4, #T_8ebad_row1_col6, #T_8ebad_row1_col10, #T_8ebad_row1_col15, #T_8ebad_row1_col16, #T_8ebad_row1_col21, #T_8ebad_row1_col23, #T_8ebad_row1_col24, #T_8ebad_row1_col26, #T_8ebad_row1_col27, #T_8ebad_row1_col28 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8ebad_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# </style>
# <table id="T_8ebad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ebad_level0_col0" class="col_heading level0 col0" >DataAvailability</th>
#       <th id="T_8ebad_level0_col1" class="col_heading level0 col1" >CAGR</th>
#       <th id="T_8ebad_level0_col2" class="col_heading level0 col2" >AnnVol</th>
#       <th id="T_8ebad_level0_col3" class="col_heading level0 col3" >Martin</th>
#       <th id="T_8ebad_level0_col4" class="col_heading level0 col4" >CapitalEfficiency</th>
#       <th id="T_8ebad_level0_col5" class="col_heading level0 col5" >MaxDD</th>
#       <th id="T_8ebad_level0_col6" class="col_heading level0 col6" >UlcerIndex</th>
#       <th id="T_8ebad_level0_col7" class="col_heading level0 col7" >VolatilityDrag</th>
#       <th id="T_8ebad_level0_col8" class="col_heading level0 col8" >PctTimeNearHighs</th>
#       <th id="T_8ebad_level0_col9" class="col_heading level0 col9" >TrendPersistence</th>
#       <th id="T_8ebad_level0_col10" class="col_heading level0 col10" >PctDaysUnderwater</th>
#       <th id="T_8ebad_level0_col11" class="col_heading level0 col11" >AvgUnderwaterDays</th>
#       <th id="T_8ebad_level0_col12" class="col_heading level0 col12" >P95UnderwaterDays</th>
#       <th id="T_8ebad_level0_col13" class="col_heading level0 col13" >MaxUnderwaterDays</th>
#       <th id="T_8ebad_level0_col14" class="col_heading level0 col14" >TTR_Days</th>
#       <th id="T_8ebad_level0_col15" class="col_heading level0 col15" >RecoverySlope_Ann</th>
#       <th id="T_8ebad_level0_col16" class="col_heading level0 col16" >RecoveryEfficiency</th>
#       <th id="T_8ebad_level0_col17" class="col_heading level0 col17" >RecoveredToPeak_inWindow</th>
#       <th id="T_8ebad_level0_col18" class="col_heading level0 col18" >ExpectedShortfall</th>
#       <th id="T_8ebad_level0_col19" class="col_heading level0 col19" >ConditionalCorr_Up</th>
#       <th id="T_8ebad_level0_col20" class="col_heading level0 col20" >ConditionalCorr_Down</th>
#       <th id="T_8ebad_level0_col21" class="col_heading level0 col21" >TrackingError_Ann</th>
#       <th id="T_8ebad_level0_col22" class="col_heading level0 col22" >InformationRatio</th>
#       <th id="T_8ebad_level0_col23" class="col_heading level0 col23" >UpsideCapture</th>
#       <th id="T_8ebad_level0_col24" class="col_heading level0 col24" >DownsideCapture</th>
#       <th id="T_8ebad_level0_col25" class="col_heading level0 col25" >PeriodCorr</th>
#       <th id="T_8ebad_level0_col26" class="col_heading level0 col26" >PeriodBeta</th>
#       <th id="T_8ebad_level0_col27" class="col_heading level0 col27" >PeriodAlpha_per_period</th>
#       <th id="T_8ebad_level0_col28" class="col_heading level0 col28" >PeriodAlpha_Ann</th>
#       <th id="T_8ebad_level0_col29" class="col_heading level0 col29" >PeriodR2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ebad_level0_row0" class="row_heading level0 row0" >VTI</th>
#       <td id="T_8ebad_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_8ebad_row0_col1" class="data row0 col1" >18.06%</td>
#       <td id="T_8ebad_row0_col2" class="data row0 col2" >11.04%</td>
#       <td id="T_8ebad_row0_col3" class="data row0 col3" >10.387</td>
#       <td id="T_8ebad_row0_col4" class="data row0 col4" >2.926</td>
#       <td id="T_8ebad_row0_col5" class="data row0 col5" >-6.17%</td>
#       <td id="T_8ebad_row0_col6" class="data row0 col6" >1.74</td>
#       <td id="T_8ebad_row0_col7" class="data row0 col7" >0.965</td>
#       <td id="T_8ebad_row0_col8" class="data row0 col8" >97.78%</td>
#       <td id="T_8ebad_row0_col9" class="data row0 col9" >54.96%</td>
#       <td id="T_8ebad_row0_col10" class="data row0 col10" >71.9%</td>
#       <td id="T_8ebad_row0_col11" class="data row0 col11" >7</td>
#       <td id="T_8ebad_row0_col12" class="data row0 col12" >22</td>
#       <td id="T_8ebad_row0_col13" class="data row0 col13" >36</td>
#       <td id="T_8ebad_row0_col14" class="data row0 col14" >42</td>
#       <td id="T_8ebad_row0_col15" class="data row0 col15" >46.56%</td>
#       <td id="T_8ebad_row0_col16" class="data row0 col16" >1.066</td>
#       <td id="T_8ebad_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_8ebad_row0_col18" class="data row0 col18" >-1.79%</td>
#       <td id="T_8ebad_row0_col19" class="data row0 col19" >1.000</td>
#       <td id="T_8ebad_row0_col20" class="data row0 col20" >1.000</td>
#       <td id="T_8ebad_row0_col21" class="data row0 col21" >0.00%</td>
#       <td id="T_8ebad_row0_col22" class="data row0 col22" >—</td>
#       <td id="T_8ebad_row0_col23" class="data row0 col23" >1.000</td>
#       <td id="T_8ebad_row0_col24" class="data row0 col24" >1.000</td>
#       <td id="T_8ebad_row0_col25" class="data row0 col25" >1.000</td>
#       <td id="T_8ebad_row0_col26" class="data row0 col26" >1.000</td>
#       <td id="T_8ebad_row0_col27" class="data row0 col27" >-0.00%</td>
#       <td id="T_8ebad_row0_col28" class="data row0 col28" >-0.00%</td>
#       <td id="T_8ebad_row0_col29" class="data row0 col29" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_8ebad_level0_row1" class="row_heading level0 row1" >VWO</th>
#       <td id="T_8ebad_row1_col0" class="data row1 col0" >100.0%</td>
#       <td id="T_8ebad_row1_col1" class="data row1 col1" >39.78%</td>
# ...
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ee94e_row0_col2, #T_ee94e_row15_col21 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_ee94e_row0_col3, #T_ee94e_row3_col8, #T_ee94e_row4_col8 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_ee94e_row0_col4, #T_ee94e_row14_col18 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_ee94e_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_ee94e_row0_col6, #T_ee94e_row0_col15, #T_ee94e_row0_col17, #T_ee94e_row0_col21, #T_ee94e_row1_col8, #T_ee94e_row1_col13, #T_ee94e_row1_col17, #T_ee94e_row1_col18, #T_ee94e_row2_col17, #T_ee94e_row3_col2, #T_ee94e_row3_col10, #T_ee94e_row3_col11, #T_ee94e_row3_col12, #T_ee94e_row3_col13, #T_ee94e_row3_col17, #T_ee94e_row4_col17, #T_ee94e_row5_col17, #T_ee94e_row6_col17, #T_ee94e_row7_col16, #T_ee94e_row7_col17, #T_ee94e_row7_col26, #T_ee94e_row8_col4, #T_ee94e_row8_col7, #T_ee94e_row8_col17, #T_ee94e_row8_col22, #T_ee94e_row9_col17, #T_ee94e_row9_col19, #T_ee94e_row10_col1, #T_ee94e_row10_col3, #T_ee94e_row10_col17, #T_ee94e_row10_col23, #T_ee94e_row10_col24, #T_ee94e_row10_col27, #T_ee94e_row10_col28, #T_ee94e_row11_col17, #T_ee94e_row11_col20, #T_ee94e_row11_col25, #T_ee94e_row11_col29, #T_ee94e_row12_col9, #T_ee94e_row12_col17, #T_ee94e_row13_col17, #T_ee94e_row14_col2, #T_ee94e_row14_col17, #T_ee94e_row15_col17 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ee94e_row0_col9, #T_ee94e_row1_col9, #T_ee94e_row3_col20, #T_ee94e_row4_col15, #T_ee94e_row4_col16 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_ee94e_row0_col18, #T_ee94e_row6_col6, #T_ee94e_row13_col16 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_ee94e_row0_col22 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ee94e_row0_col24, #T_ee94e_row5_col22 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col1, #T_ee94e_row5_col6, #T_ee94e_row12_col3 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_ee94e_row1_col4 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col5 {
#   background-color: #fef6fa;
#   color: #000000;
#   font-weight: 600;
# }
# #T_ee94e_row1_col7, #T_ee94e_row9_col2, #T_ee94e_row13_col20 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col10, #T_ee94e_row2_col10, #T_ee94e_row4_col10, #T_ee94e_row5_col10, #T_ee94e_row6_col10, #T_ee94e_row7_col10, #T_ee94e_row11_col10, #T_ee94e_row12_col10, #T_ee94e_row13_col10, #T_ee94e_row14_col10, #T_ee94e_row15_col10 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col11, #T_ee94e_row7_col29, #T_ee94e_row9_col4, #T_ee94e_row10_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_ee94e_row1_col12, #T_ee94e_row7_col7 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ee94e_row1_col15, #T_ee94e_row1_col20, #T_ee94e_row3_col21, #T_ee94e_row11_col18, #T_ee94e_row14_col21 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col16, #T_ee94e_row11_col22 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col19, #T_ee94e_row7_col27, #T_ee94e_row7_col28, #T_ee94e_row12_col26 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_ee94e_row1_col21, #T_ee94e_row5_col8, #T_ee94e_row6_col8, #T_ee94e_row10_col8 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col22 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col23 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col25, #T_ee94e_row11_col2, #T_ee94e_row14_col19 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col26, #T_ee94e_row5_col4 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col27, #T_ee94e_row1_col28, #T_ee94e_row4_col27, #T_ee94e_row4_col28 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_ee94e_row1_col29, #T_ee94e_row15_col27, #T_ee94e_row15_col28 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col1, #T_ee94e_row13_col27, #T_ee94e_row13_col28 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col2, #T_ee94e_row3_col26, #T_ee94e_row12_col7 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_ee94e_row2_col3 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col4, #T_ee94e_row2_col22, #T_ee94e_row2_col27, #T_ee94e_row2_col28 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col5 {
#   background-color: #2484ba;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_ee94e_row2_col6, #T_ee94e_row2_col16 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_ee94e_row2_col7, #T_ee94e_row9_col7 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_ee94e_row2_col8, #T_ee94e_row13_col8, #T_ee94e_row14_col8, #T_ee94e_row15_col8 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col11, #T_ee94e_row4_col11, #T_ee94e_row5_col11, #T_ee94e_row6_col11, #T_ee94e_row7_col11, #T_ee94e_row11_col11, #T_ee94e_row12_col11, #T_ee94e_row13_col11, #T_ee94e_row14_col11, #T_ee94e_row15_col11 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col12, #T_ee94e_row4_col12, #T_ee94e_row5_col12, #T_ee94e_row6_col12, #T_ee94e_row7_col12, #T_ee94e_row11_col12, #T_ee94e_row12_col12, #T_ee94e_row13_col12, #T_ee94e_row14_col12, #T_ee94e_row15_col12 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col13, #T_ee94e_row3_col3, #T_ee94e_row4_col13, #T_ee94e_row5_col13, #T_ee94e_row6_col13, #T_ee94e_row7_col13, #T_ee94e_row11_col13, #T_ee94e_row12_col13, #T_ee94e_row13_col13, #T_ee94e_row14_col13, #T_ee94e_row15_col13 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col15, #T_ee94e_row2_col20, #T_ee94e_row3_col27, #T_ee94e_row3_col28 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col18 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col19, #T_ee94e_row8_col24, #T_ee94e_row15_col25 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col21, #T_ee94e_row7_col3, #T_ee94e_row8_col20 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col23 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_ee94e_row2_col24 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_ee94e_row2_col25, #T_ee94e_row7_col4 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_ee94e_row2_col26 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_ee94e_row2_col29, #T_ee94e_row7_col15, #T_ee94e_row11_col19, #T_ee94e_row15_col20 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_ee94e_row3_col1, #T_ee94e_row5_col1 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_ee94e_row3_col4, #T_ee94e_row7_col2, #T_ee94e_row14_col23 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_ee94e_row3_col5 {
#   background-color: #04588a;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_ee94e_row3_col6 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_ee94e_row3_col7, #T_ee94e_row4_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_ee94e_row3_col9, #T_ee94e_row4_col9, #T_ee94e_row6_col9, #T_ee94e_row14_col9, #T_ee94e_row15_col9 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_ee94e_row3_col15, #T_ee94e_row10_col25, #T_ee94e_row11_col24, #T_ee94e_row14_col26 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_ee94e_row3_col16, #T_ee94e_row9_col22 {
#   back
#                                        Period       Start    End
# 0  Trump Tariffs Drawdown and AI Bubble Fears  2025-01-19  today
# <style type="text/css">
# #T_32729_row0_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_32729_row0_col2, #T_32729_row14_col22, #T_32729_row15_col1 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_32729_row0_col3, #T_32729_row2_col6, #T_32729_row15_col6 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_32729_row0_col4, #T_32729_row7_col6, #T_32729_row10_col3, #T_32729_row15_col26 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_32729_row0_col5 {
#   background-color: #c1cae2;
#   color: #000000;
#   font-weight: 600;
# }
# #T_32729_row0_col6 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_32729_row0_col7 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_32729_row0_col8, #T_32729_row1_col20 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_32729_row0_col9, #T_32729_row10_col14, #T_32729_row12_col9 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_32729_row0_col10, #T_32729_row6_col3 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_32729_row0_col11, #T_32729_row10_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_32729_row0_col12, #T_32729_row2_col23, #T_32729_row5_col29, #T_32729_row7_col19, #T_32729_row14_col29 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_32729_row0_col13, #T_32729_row1_col19, #T_32729_row2_col19, #T_32729_row9_col2 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_32729_row0_col14 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_32729_row0_col15, #T_32729_row15_col12 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_32729_row0_col16, #T_32729_row8_col3, #T_32729_row9_col18 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_32729_row0_col17, #T_32729_row0_col21, #T_32729_row1_col1, #T_32729_row1_col3, #T_32729_row1_col4, #T_32729_row1_col7, #T_32729_row1_col8, #T_32729_row1_col15, #T_32729_row1_col17, #T_32729_row1_col18, #T_32729_row1_col22, #T_32729_row1_col27, #T_32729_row1_col28, #T_32729_row2_col17, #T_32729_row3_col10, #T_32729_row3_col11, #T_32729_row3_col12, #T_32729_row3_col17, #T_32729_row3_col24, #T_32729_row4_col17, #T_32729_row5_col17, #T_32729_row6_col17, #T_32729_row7_col17, #T_32729_row8_col17, #T_32729_row9_col9, #T_32729_row9_col14, #T_32729_row9_col17, #T_32729_row10_col17, #T_32729_row11_col17, #T_32729_row12_col17, #T_32729_row12_col20, #T_32729_row12_col23, #T_32729_row12_col25, #T_32729_row12_col26, #T_32729_row12_col29, #T_32729_row13_col2, #T_32729_row13_col6, #T_32729_row13_col13, #T_32729_row13_col16, #T_32729_row13_col17, #T_32729_row13_col19, #T_32729_row14_col17, #T_32729_row15_col17, #T_32729_row16_col17 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_32729_row0_col18, #T_32729_row8_col16, #T_32729_row8_col23, #T_32729_row10_col18 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_32729_row0_col19, #T_32729_row0_col20, #T_32729_row0_col25, #T_32729_row0_col29, #T_32729_row1_col2, #T_32729_row1_col6, #T_32729_row1_col10, #T_32729_row1_col11, #T_32729_row1_col12, #T_32729_row1_col13, #T_32729_row1_col14, #T_32729_row1_col16, #T_32729_row1_col23, #T_32729_row1_col24, #T_32729_row1_col26, #T_32729_row3_col1, #T_32729_row3_col3, #T_32729_row3_col22, #T_32729_row3_col27, #T_32729_row3_col28, #T_32729_row9_col15, #T_32729_row12_col21, #T_32729_row13_col4, #T_32729_row13_col7, #T_32729_row13_col8, #T_32729_row13_col18, #T_32729_row14_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_32729_row0_col22 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_32729_row0_col23, #T_32729_row6_col7 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_32729_row0_col24 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_32729_row0_col26, #T_32729_row11_col7, #T_32729_row11_col8 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_32729_row0_col27, #T_32729_row0_col28, #T_32729_row13_col29 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_32729_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-weight: 600;
# }
# #T_32729_row1_col9, #T_32729_row3_col26, #T_32729_row4_col9, #T_32729_row6_col12 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_32729_row1_col21, #T_32729_row9_col22 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_32729_row1_col25, #T_32729_row10_col9 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_32729_row1_col29 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_32729_row2_col1, #T_32729_row13_col1 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_32729_row2_col2, #T_32729_row5_col19 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_32729_row2_col3 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_32729_row2_col4, #T_32729_row2_col29, #T_32729_row15_col16 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_32729_row2_col5 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_32729_row2_col7, #T_32729_row13_col3, #T_32729_row14_col8, #T_32729_row16_col8 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_32729_row2_col8, #T_32729_row3_col21, #T_32729_row8_col7, #T_32729_row15_col8 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_32729_row2_col9 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_32729_row2_col10 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_32729_row2_col11, #T_32729_row4_col11, #T_32729_row4_col12 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_32729_row2_col12, #T_32729_row4_col14, #T_32729_row5_col11, #T_32729_row13_col14, #T_32729_row13_col15, #T_32729_row13_col20, #T_32729_row14_col14, #T_32729_row16_col12 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_32729_row2_col13, #T_32729_row3_col14, #T_32729_row6_col11, #T_32729_row7_col13, #T_32729_row14_col11, #T_32729_row15_col13, #T_32729_row16_col13 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_32729_row2_col14, #T_32729_row7_col14, #T_32729_row12_col14, #T_32729_row15_col14, #T_32729_row16_col14 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_32729_row2_col15, #T_32729_row12_col1 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_32729_row2_col16, #T_32729_row14_col16 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_32729_row2_col18, #T_32729_row10_col7, #T_32729_row16_col3 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_32729_row2_col20, #T_32729_row9_col16, #T_32729_row9_col20 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_32729_row2_col21 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_32729_row2_col22, #T_32729_row5_col22 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_32729_row2_col24, #T_32729_row13_col25 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_32729_row2_col25 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_32729_row2_col26, #T_32729_row4_col24 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_32729_row2_col27, #T_32729_row2_col28, #T_32729_row10_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_32729_row3_col2, #T_32729_row13_col26, #T_32729_row16_col4 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_32729_row3_col4, #T_32729_row8_col1 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_32729_row3_col5 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
#   font-weight: 600;
# }
# #T_32729_row3_col6, #T_32729_row4_col6, #T_32729_row8_col12, #T_32729_row13_col11, #T_32729_row14_col12, #T_32729_row16_col6 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_32729_row3_col7 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_32729_row3_col8, #T_32729_row4_col8, #T_32729_row8_col8 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_32729_row3_col9, #T_32729_row11_col15 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_32729_row3_col13, #T_32729_row4_col13, #T_32729_row8_col14, #T_32729_row14_col13, #T_32729_row16_col10 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_32729_row3_col15 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_32729_row3_col16, #T_32729_row4_col19, #T_32729_row5_col4, #T_32729_row7_col4, #T_32729_row15_col15 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_32729_row3_col18, #T_32729_row8_col15, #T_32729_row8_col27, #T_32729_row8
# done
